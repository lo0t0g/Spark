# %%
import holidays
import statistics as st
from collections import Counter
from datetime import datetime
from datetime import date
from datetime import timedelta
from pyspark import SparkContext
import json
import zipfile
import csv
import json
from operator import add, itemgetter
import numpy as np

sc = SparkContext()

# %%
text = sc.textFile("/home/mat/Escritorio/datasets/202003_movements.json")

# %%
text
# Out:
# /home/mat/Escritorio/datasets/202003_movements.json MapPartitionsRDD[1] at textFile at NativeMethodAccessorImpl.java:0

# %% [markdown]
# ### OBTENCIÓN DE LOS FESTIVOS DE UN AÑO.
#
# Calculamos los festivos y fines de semana de un año, por ejemplo el año 2020.
#
# Tenemos las siguientes funciones:
#
# *   obtencion_fines_semana: Con la biblioteca datetime obtenemos una lista de los fines de semana de un año.
# *   vacaciones_madrid: Añadimos los festivos de la Comunidad de Madrid (2 mayo, 15 mayo y 9 noviembre).
# *   obtencion_vacaciones_madrid: Con la biblioteca holiday obtenemos los festivos de un año en España y añadimos                                    los festivos y fines de semana calculados anteriormente.
# *   festivo: Dada una fecha, nos devuelve si es festivo o no.
# *   fecha_no_string: Dada una fecha, elimina el string por medio de la biblioteca datetime.

# %%
def obtencion_fines_semana(year):
  saturday = date(year,1,1)
  saturday += timedelta(days=5-saturday.weekday())
  lista_fines_semana = []
  while saturday.year == year:
    lista_fines_semana.append(saturday)
    lista_fines_semana.append(saturday + timedelta(days=1))
    saturday += timedelta(days=7)
  return lista_fines_semana

def vacaciones_madrid(year): #Son 3 días: Almudena, San Isidro, CM.
  return [date(year,5,2), date(year,5,15), date(year,11,9)]

def obtencion_vacaciones_madrid(year):
  lista_vacaciones = list(holidays.CountryHoliday('ES', year, 'CM'))
  lista_vacaciones += vacaciones_madrid(year)
  lista_vacaciones += obtencion_fines_semana(year)
  return lista_vacaciones

def festivo(day): #Devuelve un booleano que indica si un día es festivo (True) o no (False).
    return day in lista_vacaciones 

def fecha_no_string(date): #Dado un string que representa una fecha, devuelve la misma como tipo datetime.Date.
  return datetime.strptime(date, '%Y-%m-%d').date()

# %%
lista_vacaciones = obtencion_vacaciones_madrid(2020)

# %%
lista_vacaciones
# Out:
# [datetime.date(2020, 1, 1),
#  datetime.date(2020, 1, 6),
#  datetime.date(2020, 3, 19),
#  datetime.date(2020, 4, 9),
#  datetime.date(2020, 4, 10),
#  datetime.date(2020, 4, 13),
#  datetime.date(2020, 5, 1),
#  datetime.date(2020, 8, 15),
#  datetime.date(2020, 10, 12),
#  datetime.date(2020, 11, 2),
#  datetime.date(2020, 12, 7),
#  datetime.date(2020, 12, 8),
#  datetime.date(2020, 12, 25),
#  datetime.date(2020, 6, 1),
#  datetime.date(2020, 5, 2),
#  datetime.date(2020, 5, 15),
#  datetime.date(2020, 11, 9),
#  datetime.date(2020, 1, 4),
#  datetime.date(2020, 1, 5),
#  datetime.date(2020, 1, 11),
#  datetime.date(2020, 1, 12),
#  datetime.date(2020, 1, 18),
#  datetime.date(2020, 1, 19),
#  datetime.date(2020, 1, 25),
#  datetime.date(2020, 1, 26),
#  datetime.date(2020, 2, 1),
#  datetime.date(2020, 2, 2),
#  datetime.date(2020, 2, 8),
#  datetime.date(2020, 2, 9),
#  datetime.date(2020, 2, 15),
#  datetime.date(2020, 2, 16),
#  datetime.date(2020, 2, 22),
#  datetime.date(2020, 2, 23),
#  datetime.date(2020, 2, 29),
#  datetime.date(2020, 3, 1),
#  datetime.date(2020, 3, 7),
#  datetime.date(2020, 3, 8),
#  datetime.date(2020, 3, 14),
#  datetime.date(2020, 3, 15),
#  datetime.date(2020, 3, 21),
#  datetime.date(2020, 3, 22),
#  datetime.date(2020, 3, 28),
#  datetime.date(2020, 3, 29),
#  datetime.date(2020, 4, 4),
#  datetime.date(2020, 4, 5),
#  datetime.date(2020, 4, 11),
#  datetime.date(2020, 4, 12),
#  datetime.date(2020, 4, 18),
#  datetime.date(2020, 4, 19),
#  datetime.date(2020, 4, 25),
#  datetime.date(2020, 4, 26),
#  datetime.date(2020, 5, 2),
#  datetime.date(2020, 5, 3),
#  datetime.date(2020, 5, 9),
#  datetime.date(2020, 5, 10),
#  datetime.date(2020, 5, 16),
#  datetime.date(2020, 5, 17),
#  datetime.date(2020, 5, 23),
#  datetime.date(2020, 5, 24),
#  datetime.date(2020, 5, 30),
#  datetime.date(2020, 5, 31),
#  datetime.date(2020, 6, 6),
#  datetime.date(2020, 6, 7),
#  datetime.date(2020, 6, 13),
#  datetime.date(2020, 6, 14),
#  datetime.date(2020, 6, 20),
#  datetime.date(2020, 6, 21),
#  datetime.date(2020, 6, 27),
#  datetime.date(2020, 6, 28),
#  datetime.date(2020, 7, 4),
#  datetime.date(2020, 7, 5),
#  datetime.date(2020, 7, 11),
#  datetime.date(2020, 7, 12),
#  datetime.date(2020, 7, 18),
#  datetime.date(2020, 7, 19),
#  datetime.date(2020, 7, 25),
#  datetime.date(2020, 7, 26),
#  datetime.date(2020, 8, 1),
#  datetime.date(2020, 8, 2),
#  datetime.date(2020, 8, 8),
#  datetime.date(2020, 8, 9),
#  datetime.date(2020, 8, 15),
#  datetime.date(2020, 8, 16),
#  datetime.date(2020, 8, 22),
#  datetime.date(2020, 8, 23),
#  datetime.date(2020, 8, 29),
#  datetime.date(2020, 8, 30),
#  datetime.date(2020, 9, 5),
#  datetime.date(2020, 9, 6),
#  datetime.date(2020, 9, 12),
#  datetime.date(2020, 9, 13),
#  datetime.date(2020, 9, 19),
#  datetime.date(2020, 9, 20),
#  datetime.date(2020, 9, 26),
#  datetime.date(2020, 9, 27),
#  datetime.date(2020, 10, 3),
#  datetime.date(2020, 10, 4),
#  datetime.date(2020, 10, 10),
#  datetime.date(2020, 10, 11),
#  datetime.date(2020, 10, 17),
#  datetime.date(2020, 10, 18),
#  datetime.date(2020, 10, 24),
#  datetime.date(2020, 10, 25),
#  datetime.date(2020, 10, 31),
#  datetime.date(2020, 11, 1),
#  datetime.date(2020, 11, 7),
#  datetime.date(2020, 11, 8),
#  datetime.date(2020, 11, 14),
#  datetime.date(2020, 11, 15),
#  datetime.date(2020, 11, 21),
#  datetime.date(2020, 11, 22),
#  datetime.date(2020, 11, 28),
#  datetime.date(2020, 11, 29),
#  datetime.date(2020, 12, 5),
#  datetime.date(2020, 12, 6),
#  datetime.date(2020, 12, 12),
#  datetime.date(2020, 12, 13),
#  datetime.date(2020, 12, 19),
#  datetime.date(2020, 12, 20),
#  datetime.date(2020, 12, 26),
#  datetime.date(2020, 12, 27)]

# %% [markdown]
# ### PREPARACIÓN DE LA CONSULTA DE DATOS:
#
# Útiles para cuando calculemos la media de los viajes, tipos de usuario etc, de nuestros archivos.

# %%
directorio = "/home/mat/Escritorio/datasets"

# %%
fichero = '202003_movements.json'

# %%
fichero
# Out:
# '202003_movements.json'

# %%
line = '{"_id": {"$oid": "5eeca06d618046678f83b07a"}, "user_day_code": "a880483c5b4c4a773bd66e0a353ccb13bcf98c7a6605373bb7ee7f54ebe6b07c", "idplug_base": 8, "user_type": 3, "idunplug_base": 8, "travel_time": 7612873, "idunplug_station": 136, "ageRange": 5, "idplug_station": 108, "unplug_hourTime": "2020-03-17T18:00:00Z", "zip_code": "28022"}\n'

# %%
line #una linea del json (se define más abajo)
# Out:
# '{"_id": {"$oid": "5eeca06d618046678f83b07a"}, "user_day_code": "a880483c5b4c4a773bd66e0a353ccb13bcf98c7a6605373bb7ee7f54ebe6b07c", "idplug_base": 8, "user_type": 3, "idunplug_base": 8, "travel_time": 7612873, "idunplug_station": 136, "ageRange": 5, "idplug_station": 108, "unplug_hourTime": "2020-03-17T18:00:00Z", "zip_code": "28022"}\n'

# %% [markdown]
# ### MEDIA DE USUARIOS POR FECHAS.
# Vamos a calcular la media de uso del bicimad comparando entre días laborales y festivos.
# Entonces, hallamos los siguientes datos:
# - Obtenemos el par (día, usuario) y convertimos el día de str a datetime.
# - Agrupamos por día.
# - Calculamos el número de usuarios por día.
# - Comparamos entre laboral y festivo y los agrupamos.
# - Calculamos la media de usuarios por tipo de día.
# - Devolvemos un diccionario con estrucutra:  clave: si es festivo, valor: media de usuarios por día.
# - Finalmente se calcula el porcentaje de variación entre festivos y laborables.

# %%
#Primero obtenemos el par (día, usuario), convertimos el día para que sea de tipo datetime y no string:
from datetime import datetime

def tupla_dia_usuario(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
    line = json.loads(line)
    user = line['user_day_code']
    day = line['unplug_hourTime'][0:10]
    return fecha_no_string(day), user

# %%
tupla_dia_usuario(line)
# Out:
# (datetime.date(2020, 3, 17),
#  'a880483c5b4c4a773bd66e0a353ccb13bcf98c7a6605373bb7ee7f54ebe6b07c')

# %%
# Calculamos bicimaniacos por día, decidimos si ese día es festivo, agrupamos por claves (tipo de día), calculamos la
#media y devolvemos la media en días laborables y festivos:

uso_medio = text.map(tupla_dia_usuario)\
  .groupByKey()\
  .mapValues(set)\
  .mapValues(len)\
  .map(lambda x : (x[0] in lista_vacaciones, x[1]))\
  .groupByKey()\
  .mapValues(st.mean)\
  .collectAsMap()

print(f"De media en laborables {round(uso_medio[False], 2)} bicimaniacos.")
print(f"En días festivos hay de media {round(uso_medio[True] ,2)} bicimaniacos.")
print(f"Así, se tiene que de media los bicimaniacos utilizan más la biciMAD en días \
laborables un {round(uso_medio[False]/uso_medio[True]*100 -100 ,2)}% más que \
en días festivos.")
# Out:
# De media en laborables 5544.17 bicimaniacos.
# En días festivos hay de media 3383.8 bicimaniacos.
# Así, se tiene que de media los bicimaniacos utilizan más la biciMAD en días laborables un 63.84% más que en días festivos.

# %% [markdown]
# ### COMPARACIÓN DE USOS EN DÍAS POR FRECUENCIAS.
# Vamos a comparar los días de mayor y menos uso del bicimad distinguendo si los días son laborales o festivos.
# Entonces hallamos los siguientes datos:
# - Obtenemos la fecha y la pasamos a formato no str.
# - Agrupamos por fecha.
# - Ponemos los datos de la forma: (Es festivo, día, nº uso).
# - Separamos entre días festivos y laborales.
# - Ordenamos los resultados de la forma:(día, nº uso).

# %%
def tupla_dia(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
      data = json.loads(line)
      day = data['unplug_hourTime'][0:10]
      return fecha_no_string(day), 1

# %%
result = text.map(tupla_dia)\
  .groupByKey()\
  .mapValues(sum)\
  .map(lambda x : (x[0] in lista_vacaciones,(x[0], x[1])))

laboral = sorted(result.filter(lambda x: x[0] == False)\
  .map(lambda x : (x[1][0], x[1][1]))\
  .collectAsMap()\
  .items() , key=lambda x:x[1], reverse=True)

fiesta = sorted(result.filter(lambda x: x[0] == True)\
  .map(lambda x : (x[1][0], x[1][1]))\
  .collectAsMap()\
  .items(), key=lambda x:x[1], reverse=True)

# %%
print("------------------------------------ \t ------------------------------------")
print("Top 5 días más frecuentes en laboral \t Top 5 días más frecuentes en festivo")
print("------------------------------------ \t ------------------------------------")
for i in range(5):
  print(f"\t{str(laboral[i][0])}: {laboral[i][1]}   \t\t\t {str(fiesta[i][0])}: {fiesta[i][1]}")
print("-------------------------------------- \t ---------------------------------------")
print("Top 5 días menos frecuentes en laboral \t Top 5 días menos frecuentes en festivo")
print("-------------------------------------- \t ---------------------------------------")
for i in range(5):
  print(f"\t{str(laboral[-(i+1)][0])}: {laboral[-(i+1)][1]}   \t\t\t {str(fiesta[-(i+1)][0])}: {fiesta[-(i+1)][1]}")
print("-------------------------------------- \t ---------------------------------------")
# Out:
# ------------------------------------ 	 ------------------------------------
# Top 5 días más frecuentes en laboral 	 Top 5 días más frecuentes en festivo
# ------------------------------------ 	 ------------------------------------
# 	2020-03-04: 14230   			 2020-03-07: 9059
# 	2020-03-10: 13705   			 2020-03-08: 8292
# 	2020-03-05: 13364   			 2020-03-01: 6622
# 	2020-03-06: 13129   			 2020-03-14: 2601
# 	2020-03-09: 12949   			 2020-03-15: 1096
# -------------------------------------- 	 ---------------------------------------
# Top 5 días menos frecuentes en laboral 	 Top 5 días menos frecuentes en festivo
# -------------------------------------- 	 ---------------------------------------
# 	2020-03-17: 163   			 2020-03-15: 1096
# 	2020-03-16: 301   			 2020-03-14: 2601
# 	2020-03-13: 7773   			 2020-03-01: 6622
# 	2020-03-02: 9955   			 2020-03-08: 8292
# 	2020-03-12: 9971   			 2020-03-07: 9059
# -------------------------------------- 	 ---------------------------------------

# %% [markdown]
# ### COMPARACIÓN ESTACIONES FRECUENTES.
# Vamos a comparar las estaciones más y menos utilizadas, para esto vamos a diferenciar entre desenganchar y enganchar una bicicleta en días laborales y festivos.

# %% [markdown]
# ## Caso desenganche:
# - Obtenemos el par (estación desenganche, día).
# - Comprobamos si el día es festivo.
# - Contamos cuantas veces se ha utilizado la estación cada día y clasificamos entre las 5 que más y las 5 que menos se han utlizado.

# %%
def tupla_dia_desengancha(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
      data = json.loads(line)
      day = data['unplug_hourTime'][0:10]
      unplugStation = data['idunplug_station']
      return unplugStation, fecha_no_string(day)

# %%
dias_desengancha = text.map(tupla_dia_desengancha)\
  .map(lambda x: (x[0], festivo(x[1])))\
  .groupByKey()\
  .mapValues(Counter)

# %%
laboral_desengancha = dias_desengancha.map(lambda x: (x[0],x[1][False]))
laboral_desengancha_mayor_top5 = laboral_desengancha.takeOrdered(5, lambda x: -x[1])
laboral_desengancha_menor_top5 = laboral_desengancha.takeOrdered(5,lambda x: x[1])

# %%
fiesta_desengancha = dias_desengancha.map(lambda x: (x[0], x[1][True]))
fiesta_desengancha_mayor_top5 = fiesta_desengancha.takeOrdered(5, lambda x: -x[1])
fiesta_desengancha_menor_top5 = fiesta_desengancha.takeOrdered(5, lambda x: x[1])

# %%
print("-------------------------------------------------\t --------------------------------------------------")
print("Top 5 estaciones desengancho más frecuentes en laboral \t Top 5 estaciones desengancho más frecuentes en festivo")
print("------------------------------------------------- \t -------------------------------------------------")
for i in range(len(laboral_desengancha_mayor_top5)):
  print(f"\t{laboral_desengancha_mayor_top5[i][0]}:\
   {laboral_desengancha_mayor_top5[i][1]}  \t\t\t\t\t\t\
   {fiesta_desengancha_mayor_top5[i][0]}:\
   {fiesta_desengancha_mayor_top5[i][1]}")
print("--------------------------------------------------- \t ---------------------------------------------------")
print("Top 5 estaciones desengancho menos frecuentes en laboral \t Top 5 estaciones desengancho menos frecuentes en festivo")
print("--------------------------------------------------- \t ---------------------------------------------------")
for i in range(len(laboral_desengancha_menor_top5 )):
  print(f"\t{laboral_desengancha_menor_top5 [i][0]}:\
   {laboral_desengancha_menor_top5 [i][1]}  \t\t\t\t\t\t\
   {fiesta_desengancha_menor_top5[i][0]}:{fiesta_desengancha_menor_top5[i][1]}")
print("--------------------------------------------------- \t ---------------------------------------------------")
# Out:
# -------------------------------------------------	 --------------------------------------------------
# Top 5 estaciones desengancho más frecuentes en laboral 	 Top 5 estaciones desengancho más frecuentes en festivo
# ------------------------------------------------- 	 -------------------------------------------------
# 	175:   1603  						   57:   481
# 	43:   1382  						   43:   460
# 	57:   1359  						   175:   441
# 	163:   1219  						   132:   383
# 	149:   1142  						   90:   303
# --------------------------------------------------- 	 ---------------------------------------------------
# Top 5 estaciones desengancho menos frecuentes en laboral 	 Top 5 estaciones desengancho menos frecuentes en festivo
# --------------------------------------------------- 	 ---------------------------------------------------
# 	29:   117  						   28:23
# 	28:   133  						   144:33
# 	173:   176  						   173:34
# 	144:   201  						   93:36
# 	119:   221  						   191:36
# --------------------------------------------------- 	 ---------------------------------------------------

# %% [markdown]
# ## Caso enganche:
# - Obtenemos el par (estación enganche, día).
# - Comprobamos si el día es festivo.
# - Contamos cuantas veces se ha utilizado la estación cada día y clasificamos entre las 5 que más y las 5 que menos se han utlizado.

# %%
def tupla_dia_engancha(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
      data = json.loads(line)
      day = data['unplug_hourTime'][0:10]
      plugStation = data['idplug_station']
      return plugStation, fecha_no_string(day)

# %%
dias_engancha = text.map(tupla_dia_engancha)\
  .map(lambda x: (x[0], festivo(x[1])))\
  .groupByKey()\
  .mapValues(Counter)

# %%
dia_laboral_engancha = dias_engancha.map(lambda x: (x[0],x[1][False]))
dia_laboral_engancha_mayortop5 = dia_laboral_engancha.takeOrdered(5, lambda x: -x[1])
dia_laboral_engancha_menortop5 = dia_laboral_engancha.takeOrdered(5,lambda x: x[1])


dias_fiesta_engancha = dias_engancha.map(lambda x: (x[0], x[1][True]))
dias_fiesta_engancha_mayortop5 = dias_fiesta_engancha.takeOrdered(5, lambda x: -x[1])
dias_fiesta_engancha_menortop5 = dias_fiesta_engancha.takeOrdered(5, lambda x: x[1])

# %%
print("-------------------------------------------------\t --------------------------------------------------")
print("Top 5 estaciones plug más frecuentes en laboral \t Top 5 estaciones plug más frecuentes en festivo")
print("------------------------------------------------- \t -------------------------------------------------")
for i in range(len(dia_laboral_engancha_mayortop5)):
  print(f"\t{dia_laboral_engancha_mayortop5[i][0]}:\
   {dia_laboral_engancha_mayortop5[i][1]}  \t\t\t\t\t\t\
   {dias_fiesta_engancha_mayortop5[i][0]}:\
   {dias_fiesta_engancha_mayortop5[i][1]}")
print("--------------------------------------------------- \t ---------------------------------------------------")
print("Top 5 estaciones plug menos frecuentes en laboral \t Top 5 estaciones plug menos frecuentes en festivo")
print("--------------------------------------------------- \t ---------------------------------------------------")
for i in range(len(dia_laboral_engancha_menortop5)):
  print(f"\t{dia_laboral_engancha_menortop5[i][0]}:\
   {dia_laboral_engancha_menortop5[i][1]}  \t\t\t\t\t\t\
   {dias_fiesta_engancha_menortop5[i][0]}: {dias_fiesta_engancha_menortop5[i][1]}")
print("--------------------------------------------------- \t ---------------------------------------------------")
# Out:
# -------------------------------------------------	 --------------------------------------------------
# Top 5 estaciones plug más frecuentes en laboral 	 Top 5 estaciones plug más frecuentes en festivo
# ------------------------------------------------- 	 -------------------------------------------------
# 	175:   1616  						   43:   458
# 	43:   1427  						   57:   456
# 	57:   1381  						   175:   448
# 	163:   1244  						   132:   398
# 	149:   1137  						   90:   312
# --------------------------------------------------- 	 ---------------------------------------------------
# Top 5 estaciones plug menos frecuentes en laboral 	 Top 5 estaciones plug menos frecuentes en festivo
# --------------------------------------------------- 	 ---------------------------------------------------
# 	29:   119  						   28: 17
# 	28:   123  						   144: 30
# 	173:   183  						   29: 33
# 	144:   200  						   147: 34
# 	88:   207  						   173: 35
# --------------------------------------------------- 	 ---------------------------------------------------

# %% [markdown]
# ## Top 5 trayectos más repetidos
# Queremos dar los cinco trayectos que más se repiten en nuestros datos de bicimad.
# Entonces hallamos lo siguiente:
# - Obtenemos la tupla (día, (estación desenganche,estación enganche, duración del trayecto)).
# - Descartamos los trayectos demasiado cortos (duración menos de un minuto).
# - Calculamos cuantas veces se ha hecho el trayecto en día laboral y en día festivo.
#
# Para hallar los 5 más frecuentes:
# - Hacemos un map (uno para día laboral y otro para día festivo) que tome el par de estaciones que define el trayecto y se toman los 5 con valores más altos.

# %%
def tupla_timepoEnDia(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
    line = json.loads(line)
    day = line['unplug_hourTime'][0:10]
    unplug_st = line['idunplug_station']
    plug_st = line['idplug_station']
    travel_time = line['travel_time']
    return fecha_no_string(day), (unplug_st, plug_st, travel_time)

# %%
viajes = text.map(tupla_timepoEnDia)\
  .filter(lambda x: (x[1][0]!=x[1][1]) | (x[1][2]>60))\
  .map(lambda x: ((x[1][0],x[1][1]), festivo(x[0])))\
  .groupByKey()\
  .mapValues(Counter)

viajes_laboral_top5 = viajes.map(lambda x: (x[0], x[1][False]))\
  .takeOrdered(5, lambda x: -x[1])

viajes_fiesta_top5 = viajes.map(lambda x: (x[0], x[1][True]))\
  .takeOrdered(5, lambda x: -x[1])

# %%
print("----------------------------------------- \t -----------------------------------------")
print("Top 5 trayectos más frecuentes en laboral \t Top 5 trayectos más frecuentes en festivo")
print("----------------------------------------- \t -----------------------------------------")
for i in range(5):
  print(f"\t{viajes_laboral_top5[i][0]}:\
   {viajes_laboral_top5[i][1]} \t\t\t\t\
   {viajes_fiesta_top5[i][0]}:\
   {viajes_fiesta_top5[i][1]}")
print("----------------------------------------- \t -----------------------------------------")
# Out:
# ----------------------------------------- 	 -----------------------------------------
# Top 5 trayectos más frecuentes en laboral 	 Top 5 trayectos más frecuentes en festivo
# ----------------------------------------- 	 -----------------------------------------
# 	(9, 149):   88 				   (132, 132):   57
# 	(130, 149):   69 				   (64, 64):   36
# 	(64, 75):   66 				   (175, 175):   31
# 	(64, 78):   63 				   (43, 43):   28
# 	(175, 27):   62 				   (6, 6):   26
# ----------------------------------------- 	 -----------------------------------------

# %% [markdown]
# ## Número de viajes por usuario
#
#
# Queremos saber cuantos trayectos se realizan de meda por día.
# Analizamos los casos.

# %% [markdown]
# ### Sin tener en cuenta el tipo de usuario
#
# - Obtenemos el par (día, usuario) y calculamos el número de trayectos realizados por día y usuario.
# - Tomamos el día y el número de trayectos hechos y hacemos la media.
# - Separamos entre días festivos y laborales y hacemos la media por tipo de día.

# %%
def tupla_dia_usuario(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
    line = json.loads(line)
    user = line['user_day_code']
    day = line['unplug_hourTime'][0:10]
    return fecha_no_string(day), user

# %%
media_viajes = text.map(tupla_dia_usuario)\
  .map(lambda x : ((x[0], x[1]), 1))\
  .groupByKey()\
  .mapValues(sum)\
  .map(lambda x: (x[0][0], x[1]))\
  .groupByKey()\
  .mapValues(st.mean)\
  .map(lambda x: (festivo (x[0]), x[1]))\
  .groupByKey()\
  .mapValues(st.mean)\
  .collectAsMap()

# %%
print(f"En laboral, cada usuario, de media realiza {round(media_viajes[False] ,2)} viajes")
print(f"En festivo, cada usuario, de media realiza {round(media_viajes[True] ,2)} viajes")
# Out:
# En laboral, cada usuario, de media realiza 1.9 viajes
# En festivo, cada usuario, de media realiza 1.64 viajes

# %% [markdown]
# ### Teniendo en cuenta el tipo de usuario
#
# - Obtenemos la tupla (día (en formato datetime), usuario, tipo usuario).
# - Calculamos el número de trayectos por día y por tipo de usuario.
# - Separamos entre día laboral y día festivo y realizamos la media por cada tipo de día.

# %%
def tupla_dia_tipoUsuario(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
      data = json.loads(line)
      day = data['unplug_hourTime'][0:10]
      user_type = data['user_type']
      user_id = data['user_day_code']
      return (fecha_no_string(day), user_id, user_type) , 1

# %%
media_tipoUsuario =text.map(tupla_dia_tipoUsuario)\
  .reduceByKey(lambda x,y: x+y)\
  .map(lambda x: ((x[0][0], x[0][2]), x[1]))\
  .groupByKey()\
  .mapValues(st.mean)\
  .map(lambda x: ((festivo(x[0][0]), x[0][1]), x[1]))\
  .groupByKey()\
  .mapValues(st.mean)\
  .collectAsMap()

# %%
media_tipoUsuario
# Out:
# {(False, 2): 1.7574731575275053,
#  (True, 1): 1.5174254255556958,
#  (True, 3): 16.252832991569832,
#  (True, 2): 1.6728087579870476,
#  (False, 1): 1.6050298922819155,
#  (False, 3): 21.699455112585596}

# %%
print("Las medias de usos por día del servicio por cada tipo de usuario son\
 las siguientes:")
print("     Laborable         Festivo")
print("  ---------------    ----------------")
#print(f"0:\t{round(mean_type[(False, 0)],1)} \t\t\
#   {round(mean_type[(True, 0)],1)} ")
print(f"1:\t{round(media_tipoUsuario[(False, 1)],1)} \t\t\
   {round(media_tipoUsuario[(True, 1)],1)} ")
print(f"2:\t{round(media_tipoUsuario[(False, 2)],1)} \t\t\
   {round(media_tipoUsuario[(True, 2)],1)} ")
print(f"3:\t{round(media_tipoUsuario[(False, 3)],1)} \t\t\
   {round(media_tipoUsuario[(True, 3)],1)} ")
# Out:
# Las medias de usos por día del servicio por cada tipo de usuario son las siguientes:
#      Laborable         Festivo
#   ---------------    ----------------
# 1:	1.6 		   1.5
# 2:	1.8 		   1.7
# 3:	21.7 		   16.3

# %% [markdown]
# # Usuario más frecuente

# %% [markdown]
# Queremos ver el tipo de usuario que más utiliza el servicio bicimad comparando entre días laborales y festivos.
# Para esto hacemos lo siguiente:
# - Obtenemos el par (día (en formato datetime),(tipo de usuariom, ID del usuario)).
# - Vamos a considerar tan soo el día y el tipo de usuario (1, 2 o 3).
# - Separamos entre día laboral y día festivo y con el tipo de usuario calculamos el número de veces que se usa el servicio.
#
# Lo mostramos en formato diccionario con clave booleana para indicar si laboral o festivo y diccionario con valor asociado con claves al tipo de usuario y al número de veces utilizado pot cada tipo de usuario en día laboral o festivo.

# %%
def tupla_dia_tipoUsuario_codigoUsuario(line):
 with open(fichero, 'r', errors='replace') as f:
  for data in f:
    line = json.loads(line)
    user_type = line['user_type']
    user_code = line['user_day_code']
    day = line['unplug_hourTime'][0:10]
    return fecha_no_string(day), (user_type,user_code)

# %%
tipos_usuario = text.map(tupla_dia_tipoUsuario_codigoUsuario)\
                  .map(lambda x: ((x[0],x[1][0]), x[1][1]))\
                  .groupByKey()\
                  .mapValues(lambda x: len(set(x)))\
                  .map(lambda x: ((festivo(x[0][0]), x[0][1]), x[1]))\
                  .reduceByKey(lambda x,y: x+y)\
                  .map(lambda x: (x[0][0],(x[0][1],x[1])))\
                  .groupByKey()\
                  .mapValues(dict)\
                  .collectAsMap()

# %%
print(f"En laborales, obtenemos el siguiente orden de tipos de usuario (de \
más a menos usos):")
tipos_ordenados = "  "
for pair in sorted(tipos_usuario[False].items(), key = lambda x: x[1], reverse = True):
  tipos_ordenados += str(pair[0]) + ", "
print(tipos_ordenados[:-2])

print(f"En festivos, obtenemos el siguiente orden de tipos de usuario (de \
más a menos usos):")
tipos_ordenados = "  "
for pair in sorted(tipos_usuario[True].items(), key = lambda x: x[1], reverse = True):
  tipos_ordenados += str(pair[0]) + ", "
print(tipos_ordenados[:-2])
# Out:
# En laborales, obtenemos el siguiente orden de tipos de usuario (de más a menos usos):
#   1, 3, 2
# En festivos, obtenemos el siguiente orden de tipos de usuario (de más a menos usos):
#   1, 2, 3

# %% [markdown]
# # Número total de bucles

# %% [markdown]
# Entendemos po ciclo una secuencia de trayectos tal que el final de uno y el inicio del siguiente coinciden. De manera que se repite una estación en la concatenación de viajes.
#
# Mostramos el siguiente ejemplo:
#
# [0,1], [1,8], [4,7], [2,8], [8,2], [2,3], [6,7]
#
# sería:
#
# [0,1,8], [4,7], [2,8,2,3], [6,7]
#
# Y solo hay un ciclo, dado en:
#
# [2,8,2,3]

# %% [markdown]
# Definiremos funciones:
#
#
# *   pares_concatenados: Si es posible concatena pares de trayectos. Si no es posble devuelve la lista vacía.
# *   trayectos_concatenados: Dada una lista (secuencia) de trayectos, concatena si es posible los trayectos.
# *   numero_ciclos: Cuenta los ciclos que hay en una secuencia de trayectos ya concatenados.

# %%
#CONCATENA PARES DE VIAJES SI ES POSIBLE; SI NO DEVUELVE BOOL FALSE
def pares_concatenados(list1, list2):
  if list1[-1] == list2[0]:
    return list1 + list2[1:]
  else:
     return []

#DADA UNA LISTA CON PARES (salida, llegada) CONCATENA LOS VIAJES SI ES POSIBLES
def trayectos_concatenados(lista):
  concat = []
  i = 0
  while i < len(lista):

    if i < len(lista)-1:
      union = pares_concatenados(lista[i], lista[i+1])
      if  union == []:
        if len(lista[i]) > 2:          
          concat.append(lista[i])
        else:
          if lista[i][0] == lista[i][1]:
            concat.append(lista[i])
      else:
        lista[i+1] = union
        if i + 1 == len(lista) - 1:
          concat.append(lista[i+1])
    else:
      if lista[i][0] == lista[i][1]:
        concat.append(lista[i])
    i = i + 1    
  return concat

#CUENTA LOS CICLOS 
def numero_ciclos(lista):
  contador = 0
  lista = trayectos_concatenados(lista)
  for elemento in lista:
    num_ciclos = 0
    vistos = []
    for i in elemento:
      if i in vistos:
        num_ciclos = num_ciclos + 1
      else:
        vistos.append(i)
    contador = contador + num_ciclos
  return contador

# %%
#Ejemplo
numero_ciclos([[1,3],[3,1],[1,4],[2,2],[1,5],[5,9]])
# Out:
# 2

# %%
#Ejemplo
trayectos_concatenados([[1,3],[3,1],[1,4],[2,2],[1,5],[5,9]])
# Out:
# [[1, 3, 1, 4], [2, 2], [1, 5, 9]]

# %% [markdown]
# Ahora, queremos hallar los ciclos que hay en nuestros datos.
# - Calculamos el par (día, ID del usuario, [salida, llegada]).

# %%
def tupla_dias_idUsuarioViaje(line):
    data = json.loads(line)
    uid = data['user_day_code']     
    day = data['unplug_hourTime'][0:10]
    start = data['idunplug_station']
    end = data['idplug_station'] 
    return  fecha_no_string(day), uid, [start, end]

# %%
data = json.loads(line)
data['unplug_hourTime'][0:10]
# Out:
# '2020-03-17'

# %% [markdown]
# Definimos los siguientes funciones:
# * crea: toma como input una lista de listas del tipo [usuario,[salida, llegada]] y junta los trayectos hechos por el mismo usuario, devolviendo la información en un diccionario.
# * suma_ciclos: toma un diccionario tipo clave: usuario y valor asociado a una lista de trayectos y obtiene el número total de ciclos.

# %%
def crea(lista):
  dic = dict()
  i = 0
  while i < len(lista):
    if lista[i][0] in dic:
      dic[lista[i][0]].append(lista[i][1])
    else:
      dic[lista[i][0]] = [lista[i][1]]
    i = i+1
  return dic

# %%
def suma_ciclos(lista_dic):
  suma = 0
  for i in lista_dic:
    suma = suma + numero_ciclos(lista_dic[i])
  return suma

# %% [markdown]
# - Obtenemos la tupla (día, ID del usuario, [salida,llegada]) que hemos calculado más arriba.
# - Clasificamos entre días laborales y días festivos, y agrupamos.
# - Dentro de cada sección (laboral, festivo) agrupamos los trayectos hechos por el mismo usuario con la función anteriormente definida, crea.
# - Contamos los ciclos realizados por cada usuario y los sumamos.

# %%
ciclos = text.map(tupla_dias_idUsuarioViaje)\
.map(lambda x: ((festivo(x[0]), (x[1], x[2]))))\
.groupByKey()\
.map(lambda x: (x[0], crea(list(x[1]))))\
.map(lambda x: (x[0], suma_ciclos(x[1])))

# %%
print('Ciclos realizados en días festivos: ' + str(ciclos.collect()[1][1]))

print('Ciclos realizados en días laborables: ' + str(ciclos.collect()[0][1]))
# Out:
# Ciclos realizados en días festivos: 4107
# Ciclos realizados en días laborables: 19780

# %% [markdown]
# ÁNALISIS DE UNA SEMANA

# %%
ruta="/home/mat/Escritorio/datasets"
Umbral_estaciones = 73 
Umbral_distritos = 738

# %%
import calendar
año= input("Escribe 2018,2019 o 2020 para seleccionar el año sobre el que quieres realizar el estudio:")
mes = int(input("Escribe el número del mes sobre el que quieres realizar el estudio: "))
dia_inicial = int(input("Introduzca el primer día de la semana a analizar,entre 1 y 22:"))
dia_final = dia_inicial+6
nombre_mes = calendar.month_name[mes]
print(f"Analizaremos la semana del {dia_inicial} al {dia_final} del mes {nombre_mes} y año {año}")
# Out:
# Escribe 2018,2019 o 2020 para seleccionar el año sobre el que quieres realizar el estudio:2020
# Escribe el número del mes sobre el que quieres realizar el estudio: 3
# Introduzca el primer día de la semana a analizar,entre 1 y 22:13
# Analizaremos la semana del 13 al 19 del mes March y año 2020

# %% [markdown]
# Creamos un json de la semana elegida

# %%
import os

os.chdir(ruta)
#seleccionamos el fichero del mes en el que se encuentra la semana
if mes<10:
    fichero = ('202003_movements.json')
else:
    fichero = ('202003_movements.json')

# %%
#lista con las líneas del json de la semana
lista_json_semana=[]
with open(fichero, 'r', errors='replace') as f:
  for line in f:
    linea = json.loads(line)
    mes1=int(linea['unplug_hourTime'][5:7]) #sacamos el mes del json
    dia1=int(linea['unplug_hourTime'][8:10]) #sacamos el día del json  
    if mes1 == mes:
      if dia_inicial<= dia1 and dia1 <= dia_final: #vemos que se encuentre dentro de los parámentros
        lista_json_semana.append(line)

# %%
lista_json_semana
# Out:
# ['{"_id": {"$oid": "5eec831756bdeb043ff16499"}, "user_day_code": "80b68d43f8fff7de897a80f92b3364b57b89aa0ea40e2db68d7d4a43bb48490f", "idplug_base": 2, "user_type": 1, "idunplug_base": 27, "travel_time": 282, "idunplug_station": 35, "ageRange": 5, "idplug_station": 16, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff1649a"}, "user_day_code": "70837e26eca3efe50a5f8f37136e2099b6629c360d0e7b391aa4a8483ba63310", "idplug_base": 19, "user_type": 1, "idunplug_base": 14, "travel_time": 131, "idunplug_station": 143, "ageRange": 0, "idplug_station": 142, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff1649b"}, "user_day_code": "bb48942d6a1f87097aac8011b416a9ece668d536f7a416946a342217885c21c6", "idplug_base": 25, "user_type": 1, "idunplug_base": 9, "travel_time": 450, "idunplug_station": 13, "ageRange": 0, "idplug_station": 218, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff1649f"}, "user_day_code": "5ce5a44167b2b30233fc178fd6ecec03bedc54c91135832912920c20f147f87e", "idplug_base": 19, "user_type": 1, "idunplug_base": 11, "travel_time": 315, "idunplug_station": 60, "ageRange": 5, "idplug_station": 132, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28004"}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164a3"}, "user_day_code": "b4c7a051d82fe4f3f5c4681f11e551ed0d50a322055f46533f4f2c85dfa9bda1", "idplug_base": 8, "user_type": 1, "idunplug_base": 6, "travel_time": 259, "idunplug_station": 107, "ageRange": 4, "idplug_station": 19, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164a4"}, "user_day_code": "01c238db946a49890e035b778bcdead46113ca9abdf65d3535e18dc40c07562c", "idplug_base": 24, "user_type": 1, "idunplug_base": 22, "travel_time": 503, "idunplug_station": 114, "ageRange": 3, "idplug_station": 206, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28010"}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164a6"}, "user_day_code": "e45bcd1464068f45021feb62a557fdbb981e20f3418cbaf60274657d9a8f62a2", "idplug_base": 11, "user_type": 1, "idunplug_base": 14, "travel_time": 606, "idunplug_station": 59, "ageRange": 0, "idplug_station": 203, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164a8"}, "user_day_code": "525d9b593b430f2cbc857116f1fe23085d77f5ae1b6067e845bf30deab1776f6", "idplug_base": 6, "user_type": 1, "idunplug_base": 24, "travel_time": 558, "idunplug_station": 30, "ageRange": 5, "idplug_station": 168, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28015"}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164a9"}, "user_day_code": "a7b1978ff63ec51a79b4b1a27782d7dac5df99b6c34553a8b9bad1d3a3d247bf", "idplug_base": 4, "user_type": 1, "idunplug_base": 8, "travel_time": 445, "idunplug_station": 163, "ageRange": 0, "idplug_station": 213, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164ab"}, "user_day_code": "4f7c324e0354af7dbe5eaa37f8bbb75fd6fbc558f2faf63565f54978eb89b3c1", "idplug_base": 22, "user_type": 1, "idunplug_base": 16, "travel_time": 344, "idunplug_station": 150, "ageRange": 0, "idplug_station": 143, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164ac"}, "user_day_code": "2e76eb978ccc44032a87eda613f6a155b3e9315d39fc52cf3f1b6232b0460a3d", "idplug_base": 14, "user_type": 1, "idunplug_base": 16, "travel_time": 658, "idunplug_station": 9, "ageRange": 0, "idplug_station": 106, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164ad"}, "user_day_code": "9fc1ca6c09c773572b60e5d5d7e63dbdfb368a838937c3fa6f80bd693c67c171", "idplug_base": 16, "user_type": 1, "idunplug_base": 21, "travel_time": 728, "idunplug_station": 163, "ageRange": 0, "idplug_station": 215, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164ae"}, "user_day_code": "c7e3bd3a2bae166f7acb25dc4635f59f11a0e9f65e3d0b26c48d51994e0581f2", "idplug_base": 19, "user_type": 1, "idunplug_base": 11, "travel_time": 870, "idunplug_station": 114, "ageRange": 0, "idplug_station": 47, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164af"}, "user_day_code": "8e75d21c78d4e8241c7d7dc754a94d029d26cf210475e44c8106c0b40098aba7", "idplug_base": 21, "user_type": 1, "idunplug_base": 6, "travel_time": 416, "idunplug_station": 39, "ageRange": 5, "idplug_station": 122, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28008"}\n',
#  '{"_id": {"$oid": "5eec831756bdeb043ff164b0"}, "user_day_code": "e0350c42b4e186a7e1cb7d35ab7d9df896010de1580f481a61cc47b15f116af8", "idplug_base": 14, "user_type": 1, "idunplug_base": 3, "travel_time": 399, "idunplug_station": 59, "ageRange": 0, "idplug_station": 21, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164b5"}, "user_day_code": "77002a720a8a7797c0f74630c2c4d96dd0b2f13744ab390adc26e53a8b573b84", "idplug_base": 17, "user_type": 1, "idunplug_base": 19, "travel_time": 905, "idunplug_station": 27, "ageRange": 0, "idplug_station": 56, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164b6"}, "user_day_code": "ae97b47744ec6c7b045255e04429027c06cecd5150e940178af7de678a0eddd3", "idplug_base": 22, "user_type": 1, "idunplug_base": 13, "travel_time": 975, "idunplug_station": 109, "ageRange": 0, "idplug_station": 197, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164b7"}, "user_day_code": "97fe3f3581124e88d6208edd8059818558d70e14463adfc6f99f890bb1bdfb2e", "idplug_base": 8, "user_type": 1, "idunplug_base": 9, "travel_time": 740, "idunplug_station": 162, "ageRange": 4, "idplug_station": 13, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28003"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164b8"}, "user_day_code": "893bbfd16cdd1a014e814b5c73461bd7bd1c7b327fc500e787b72af5bf2e340d", "idplug_base": 19, "user_type": 1, "idunplug_base": 26, "travel_time": 787, "idunplug_station": 95, "ageRange": 0, "idplug_station": 187, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164b9"}, "user_day_code": "5aa71559ea89f8165636bcfa301de7e5696d3d0f5fde1109ab8905bf5fb4c206", "idplug_base": 7, "user_type": 1, "idunplug_base": 2, "travel_time": 229, "idunplug_station": 10, "ageRange": 3, "idplug_station": 175, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28033"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ba"}, "user_day_code": "9aeff6104787bd6d794acce5694c9553dd6cd26c7ee9c770efdc2419eeaca972", "idplug_base": 24, "user_type": 1, "idunplug_base": 6, "travel_time": 435, "idunplug_station": 9, "ageRange": 3, "idplug_station": 115, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28523"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164be"}, "user_day_code": "227090337c190e96701060ffe37fcb7d15a54c259a44d373f2edccb56ded9809", "idplug_base": 4, "user_type": 1, "idunplug_base": 8, "travel_time": 586, "idunplug_station": 195, "ageRange": 0, "idplug_station": 130, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164c0"}, "user_day_code": "c57cc35c7787ee700379ed925d82edba18541081492b2ed6355335836c3ae7b7", "idplug_base": 3, "user_type": 1, "idunplug_base": 19, "travel_time": 932, "idunplug_station": 114, "ageRange": 0, "idplug_station": 15, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164c1"}, "user_day_code": "628eb263fc8888b300de254dc07989cb64cc9e68bd94ef6eca65e5c7b9398352", "idplug_base": 4, "user_type": 1, "idunplug_base": 6, "travel_time": 242, "idunplug_station": 134, "ageRange": 4, "idplug_station": 183, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28005"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164c2"}, "user_day_code": "25b2dff4d05344e459185c7e52b88f5aca0afb434df567a405be40a6ca7b4f8a", "idplug_base": 7, "user_type": 1, "idunplug_base": 21, "travel_time": 320, "idunplug_station": 150, "ageRange": 0, "idplug_station": 139, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164c5"}, "user_day_code": "e0749e7cf8067ca41e7fe0eb213fd2b6c8cd1e4965c824478a56cd72f8fcb006", "idplug_base": 22, "user_type": 1, "idunplug_base": 21, "travel_time": 1056, "idunplug_station": 124, "ageRange": 5, "idplug_station": 82, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164c7"}, "user_day_code": "edf0b672defc60b550e6d1dfe3cfbc9fd7e95cb5b3012ab78eb639d6e2b92ce4", "idplug_base": 6, "user_type": 1, "idunplug_base": 9, "travel_time": 757, "idunplug_station": 21, "ageRange": 0, "idplug_station": 47, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164c8"}, "user_day_code": "20cfa9136d15218512a62c07ac666a8fc6dd4c11dd9d7f23e6fb5d5a2989be39", "idplug_base": 18, "user_type": 1, "idunplug_base": 4, "travel_time": 678, "idunplug_station": 87, "ageRange": 3, "idplug_station": 196, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164c9"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 14, "user_type": 3, "idunplug_base": 14, "travel_time": 12, "idunplug_station": 89, "ageRange": 5, "idplug_station": 89, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164cb"}, "user_day_code": "197b6c7491f01d3010d6ccd5e46520b247ea767fdb822d5614bd3f249ed7f1eb", "idplug_base": 3, "user_type": 1, "idunplug_base": 1, "travel_time": 856, "idunplug_station": 62, "ageRange": 0, "idplug_station": 88, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164cc"}, "user_day_code": "cc4302d8ded90d8e6e8a60eee05113812e83e238cb45ca0e87d23f67039d550c", "idplug_base": 14, "user_type": 1, "idunplug_base": 17, "travel_time": 699, "idunplug_station": 122, "ageRange": 0, "idplug_station": 35, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164cd"}, "user_day_code": "f03779c291ac4c0dc7da5854fd58cf8f54f378f3d2aa486eb37c01b488673218", "idplug_base": 13, "user_type": 1, "idunplug_base": 11, "travel_time": 758, "idunplug_station": 19, "ageRange": 0, "idplug_station": 89, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ce"}, "user_day_code": "6bb5bb45aeee69d8ce3b80609372fe953f95ff5c9be47ee1b6d9e72a7e3e3c3d", "idplug_base": 16, "user_type": 1, "idunplug_base": 21, "travel_time": 830, "idunplug_station": 122, "ageRange": 0, "idplug_station": 7, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164cf"}, "user_day_code": "be32cdf68532c978d3f0729336df92810aa40d1230ad848c18184bfe79150ef6", "idplug_base": 20, "user_type": 1, "idunplug_base": 4, "travel_time": 794, "idunplug_station": 122, "ageRange": 0, "idplug_station": 7, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d0"}, "user_day_code": "05122321872f623a2b30837e6435e0da349d03042ca47d00e2740a47e976bfe3", "idplug_base": 18, "user_type": 1, "idunplug_base": 3, "travel_time": 354, "idunplug_station": 96, "ageRange": 0, "idplug_station": 199, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d2"}, "user_day_code": "44e2b179370a30f7cb115ea417f370d4581b7621d69ef25dff238caac2ceaf1a", "idplug_base": 7, "user_type": 1, "idunplug_base": 11, "travel_time": 431, "idunplug_station": 57, "ageRange": 0, "idplug_station": 83, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d3"}, "user_day_code": "f87c5b137666841ba4a603d8fef83393d7e62b697977c2fa514a8eb90cbd18a4", "idplug_base": 7, "user_type": 1, "idunplug_base": 1, "travel_time": 277, "idunplug_station": 109, "ageRange": 0, "idplug_station": 91, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d4"}, "user_day_code": "f03ce9874456d8c0ea5be08eafe6758741f0d214b1037e5e63077282d7b55609", "idplug_base": 11, "user_type": 1, "idunplug_base": 20, "travel_time": 907, "idunplug_station": 62, "ageRange": 0, "idplug_station": 57, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d5"}, "user_day_code": "87dc34f19111e65dfc8c587770e549185ae75da80b1d6c68947c1f8c3ee3d418", "idplug_base": 17, "user_type": 1, "idunplug_base": 4, "travel_time": 645, "idunplug_station": 189, "ageRange": 4, "idplug_station": 128, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28045"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d6"}, "user_day_code": "8720c365884a00c88aa7e939dcd06116bc0111a9f50f30f9f024abd54d23eb32", "idplug_base": 11, "user_type": 1, "idunplug_base": 2, "travel_time": 649, "idunplug_station": 48, "ageRange": 0, "idplug_station": 187, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d7"}, "user_day_code": "16293064e5109e58b67cc4eac8d625201acffa9e42887483d2d8a0eb0321113d", "idplug_base": 5, "user_type": 1, "idunplug_base": 1, "travel_time": 690, "idunplug_station": 189, "ageRange": 0, "idplug_station": 47, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d8"}, "user_day_code": "8c7bd8df81afae6ed613b3cd9415f99560fc208ce9b06ff730015695e4d573fc", "idplug_base": 21, "user_type": 1, "idunplug_base": 19, "travel_time": 860, "idunplug_station": 115, "ageRange": 0, "idplug_station": 187, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164d9"}, "user_day_code": "327438e5a7de8bec83069adbeaef2d47d760ec129c0e74c0acdf5631645ab651", "idplug_base": 1, "user_type": 1, "idunplug_base": 1, "travel_time": 322, "idunplug_station": 50, "ageRange": 5, "idplug_station": 174, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28005"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164da"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 20, "user_type": 3, "idunplug_base": 20, "travel_time": 22, "idunplug_station": 81, "ageRange": 5, "idplug_station": 81, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164db"}, "user_day_code": "b915f0ab07c786e1900e246d813b120176430531372e958bd50c7b91554b8918", "idplug_base": 17, "user_type": 1, "idunplug_base": 29, "travel_time": 855, "idunplug_station": 95, "ageRange": 4, "idplug_station": 187, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28053"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164dc"}, "user_day_code": "5adbcc4b9617e71fcd5ff4a56f77d5644d84b267e041811540adf55a453936f6", "idplug_base": 12, "user_type": 1, "idunplug_base": 13, "travel_time": 1103, "idunplug_station": 202, "ageRange": 0, "idplug_station": 51, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164dd"}, "user_day_code": "c3ed7bdaf88c4d5e114ea1131af1ceadc7a47c1665f95ec93a5e6d5111ec989c", "idplug_base": 20, "user_type": 1, "idunplug_base": 10, "travel_time": 938, "idunplug_station": 189, "ageRange": 0, "idplug_station": 177, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164df"}, "user_day_code": "5bbba79d5b52267ecc1e4b9268ff537fa83775b7b5d2b520a5a08091baa5b18c", "idplug_base": 1, "user_type": 1, "idunplug_base": 11, "travel_time": 461, "idunplug_station": 134, "ageRange": 5, "idplug_station": 43, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e0"}, "user_day_code": "1ba3f388d5fbbb2742771ca564a526647f7b7cf08e961deb05d4c143035fcaef", "idplug_base": 10, "user_type": 1, "idunplug_base": 2, "travel_time": 919, "idunplug_station": 35, "ageRange": 0, "idplug_station": 47, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e1"}, "user_day_code": "ebf8b123b61a69df24bfd82973e73b6f39d6e65ac06366891a8652ec49f07e87", "idplug_base": 13, "user_type": 1, "idunplug_base": 20, "travel_time": 1107, "idunplug_station": 122, "ageRange": 0, "idplug_station": 187, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e2"}, "user_day_code": "2204f66d9180886965d8cd8ace691b87c16087c8972a960d06bae9dfcf1633e0", "idplug_base": 15, "user_type": 1, "idunplug_base": 26, "travel_time": 234, "idunplug_station": 90, "ageRange": 4, "idplug_station": 106, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28006"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e3"}, "user_day_code": "e2fcc2a144731f84f084f3adf59b4bc6eff2e2f90f2fc0ad1c1259ca058bbbfb", "idplug_base": 19, "user_type": 1, "idunplug_base": 19, "travel_time": 376, "idunplug_station": 161, "ageRange": 0, "idplug_station": 149, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e4"}, "user_day_code": "ef5919d5af75039157b76dd48d14d6b0f55eb57f719c7db57d4bed7d46b5a859", "idplug_base": 21, "user_type": 1, "idunplug_base": 19, "travel_time": 415, "idunplug_station": 63, "ageRange": 0, "idplug_station": 47, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e5"}, "user_day_code": "70837e26eca3efe50a5f8f37136e2099b6629c360d0e7b391aa4a8483ba63310", "idplug_base": 23, "user_type": 1, "idunplug_base": 6, "travel_time": 489, "idunplug_station": 142, "ageRange": 0, "idplug_station": 216, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e6"}, "user_day_code": "a96a70cd11b16dc3fb3ac7c0fbd69d5f20a6a658e633b20f2a55be6fa5da53bb", "idplug_base": 1, "user_type": 1, "idunplug_base": 1, "travel_time": 879, "idunplug_station": 63, "ageRange": 0, "idplug_station": 181, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e7"}, "user_day_code": "3af23233c4db68e437a6237e32b419c30786defdfb1207375c767bca2bc41871", "idplug_base": 18, "user_type": 1, "idunplug_base": 3, "travel_time": 372, "idunplug_station": 157, "ageRange": 5, "idplug_station": 207, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164e9"}, "user_day_code": "631f7d4718502190833c4e7830795256304f204c8323f48f6d6e429a3b6454f3", "idplug_base": 15, "user_type": 1, "idunplug_base": 9, "travel_time": 329, "idunplug_station": 57, "ageRange": 0, "idplug_station": 177, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ea"}, "user_day_code": "8f093414c91ffacc12295577ec7a320909014ceea9691609fd9929adca5c3c1c", "idplug_base": 7, "user_type": 1, "idunplug_base": 13, "travel_time": 621, "idunplug_station": 16, "ageRange": 3, "idplug_station": 135, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28015"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164eb"}, "user_day_code": "f12d6add00563a9475353f2cee4fb3e5422f05784333687905e2484e510991dd", "idplug_base": 17, "user_type": 1, "idunplug_base": 3, "travel_time": 652, "idunplug_station": 77, "ageRange": 0, "idplug_station": 49, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ec"}, "user_day_code": "023fa0082f01ad67db0adbe51631e7e2ee68815344be56a009353c2a390afb3c", "idplug_base": 9, "user_type": 1, "idunplug_base": 1, "travel_time": 654, "idunplug_station": 161, "ageRange": 0, "idplug_station": 125, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ed"}, "user_day_code": "3e0f661c3ef309e76189845aca84235d9e0ed5a7c8e4c8e3cffb1f00a0bb8c1c", "idplug_base": 1, "user_type": 1, "idunplug_base": 6, "travel_time": 443, "idunplug_station": 206, "ageRange": 3, "idplug_station": 200, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28901"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ee"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 26, "user_type": 3, "idunplug_base": 21, "travel_time": 1006, "idunplug_station": 81, "ageRange": 5, "idplug_station": 102, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ef"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 18, "user_type": 3, "idunplug_base": 22, "travel_time": 1382, "idunplug_station": 81, "ageRange": 5, "idplug_station": 135, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f0"}, "user_day_code": "3af23233c4db68e437a6237e32b419c30786defdfb1207375c767bca2bc41871", "idplug_base": 14, "user_type": 1, "idunplug_base": 18, "travel_time": 128, "idunplug_station": 207, "ageRange": 5, "idplug_station": 117, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f3"}, "user_day_code": "bbd377dc8d35daa08ae1c311fa7e8b57786c9f4bb66b20b81c172f2f50cdc7f5", "idplug_base": 24, "user_type": 1, "idunplug_base": 8, "travel_time": 864, "idunplug_station": 192, "ageRange": 0, "idplug_station": 168, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f4"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 24, "user_type": 3, "idunplug_base": 19, "travel_time": 1127, "idunplug_station": 81, "ageRange": 5, "idplug_station": 102, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f5"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 25, "user_type": 3, "idunplug_base": 18, "travel_time": 1096, "idunplug_station": 81, "ageRange": 5, "idplug_station": 102, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f6"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 23, "user_type": 3, "idunplug_base": 12, "travel_time": 1252, "idunplug_station": 81, "ageRange": 5, "idplug_station": 102, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f7"}, "user_day_code": "84f71dd94196f7912c32d5c2ce407427b1470e9ff9c7f30d54232138eb3feaf1", "idplug_base": 23, "user_type": 1, "idunplug_base": 13, "travel_time": 1292, "idunplug_station": 134, "ageRange": 4, "idplug_station": 106, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28028"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f8"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 22, "user_type": 3, "idunplug_base": 17, "travel_time": 1280, "idunplug_station": 81, "ageRange": 5, "idplug_station": 102, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f9"}, "user_day_code": "10c789d87d938fc29edac7b3587861c0cdd31a0d010af31dae862ce8acfee413", "idplug_base": 15, "user_type": 1, "idunplug_base": 7, "travel_time": 796, "idunplug_station": 91, "ageRange": 0, "idplug_station": 196, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164fa"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 21, "user_type": 3, "idunplug_base": 12, "travel_time": 2017, "idunplug_station": 89, "ageRange": 5, "idplug_station": 102, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164fc"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 20, "user_type": 3, "idunplug_base": 13, "travel_time": 2050, "idunplug_station": 89, "ageRange": 5, "idplug_station": 102, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164fd"}, "user_day_code": "b8a591087f0ddf38cd48669e4eb7fb1639b0ac8d17cd43808d052aa865d03f8d", "idplug_base": 14, "user_type": 1, "idunplug_base": 20, "travel_time": 424, "idunplug_station": 113, "ageRange": 4, "idplug_station": 189, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28006"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164ff"}, "user_day_code": "f83f09c13e6d13516332bd977890b4a46a62876f5c7ff7bc074b9710a7f107f2", "idplug_base": 5, "user_type": 1, "idunplug_base": 7, "travel_time": 497, "idunplug_station": 45, "ageRange": 0, "idplug_station": 80, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff16500"}, "user_day_code": "4457d0b84c04b1f31d66ea1fe27bc40a05902552d9c29d18fe66dbd2164fb567", "idplug_base": 17, "user_type": 1, "idunplug_base": 17, "travel_time": 914, "idunplug_station": 179, "ageRange": 0, "idplug_station": 132, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff16501"}, "user_day_code": "bd1c516c1dc670d3e89778a2536b58edad6f79b0b15e8fdcc83615a816a67acb", "idplug_base": 24, "user_type": 1, "idunplug_base": 20, "travel_time": 936, "idunplug_station": 128, "ageRange": 0, "idplug_station": 170, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16506"}, "user_day_code": "8959e1697a6064154d2b4690d19c9296bdbaef39e6f8a88f4c78f9318aca4997", "idplug_base": 9, "user_type": 1, "idunplug_base": 16, "travel_time": 767, "idunplug_station": 62, "ageRange": 0, "idplug_station": 185, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16509"}, "user_day_code": "29278885e75df7a548173c305a56010121494f4e1d50ce7008a5b14ec78881b5", "idplug_base": 22, "user_type": 1, "idunplug_base": 20, "travel_time": 962, "idunplug_station": 133, "ageRange": 0, "idplug_station": 76, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1650a"}, "user_day_code": "26b012cdf6eb9a00629e475901f112c397fa3cdb1afc37b6ad9a7e3deace9ec2", "idplug_base": 21, "user_type": 1, "idunplug_base": 18, "travel_time": 962, "idunplug_station": 133, "ageRange": 0, "idplug_station": 76, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1650f"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 1, "user_type": 3, "idunplug_base": 15, "travel_time": 2757, "idunplug_station": 89, "ageRange": 5, "idplug_station": 95, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16512"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 3, "user_type": 3, "idunplug_base": 22, "travel_time": 3437, "idunplug_station": 82, "ageRange": 5, "idplug_station": 95, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16513"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 4, "user_type": 3, "idunplug_base": 21, "travel_time": 3473, "idunplug_station": 82, "ageRange": 5, "idplug_station": 95, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16515"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 5, "user_type": 3, "idunplug_base": 20, "travel_time": 3588, "idunplug_station": 82, "ageRange": 5, "idplug_station": 95, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16517"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 6, "user_type": 3, "idunplug_base": 18, "travel_time": 3662, "idunplug_station": 82, "ageRange": 5, "idplug_station": 95, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16524"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 24, "user_type": 3, "idunplug_base": 13, "travel_time": 5228, "idunplug_station": 187, "ageRange": 5, "idplug_station": 164, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16528"}, "user_day_code": "e9ee27e7208879a87f99cb0eb68418b1df0fffdb948dd70f7bfb18e251fd67b1", "idplug_base": 12, "user_type": 1, "idunplug_base": 9, "travel_time": 3241, "idunplug_station": 185, "ageRange": 3, "idplug_station": 217, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": "28045"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16529"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 1, "user_type": 3, "idunplug_base": 11, "travel_time": 5299, "idunplug_station": 187, "ageRange": 5, "idplug_station": 164, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1652a"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 2, "user_type": 3, "idunplug_base": 17, "travel_time": 5406, "idunplug_station": 187, "ageRange": 5, "idplug_station": 164, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1652b"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 10, "user_type": 3, "idunplug_base": 11, "travel_time": 2940, "idunplug_station": 197, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1652d"}, "user_day_code": "57c6bf982dc085eb28a3665f49342dcfb1aa1e3c17e2bf8fd032a8db4b711fd1", "idplug_base": 3, "user_type": 3, "idunplug_base": 15, "travel_time": 5441, "idunplug_station": 187, "ageRange": 5, "idplug_station": 164, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1652e"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 6, "user_type": 3, "idunplug_base": 9, "travel_time": 2982, "idunplug_station": 197, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1652f"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 2, "user_type": 3, "idunplug_base": 10, "travel_time": 3012, "idunplug_station": 197, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1653a"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 2, "user_type": 3, "idunplug_base": 15, "travel_time": 4139, "idunplug_station": 196, "ageRange": 5, "idplug_station": 147, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1653b"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 14, "user_type": 3, "idunplug_base": 16, "travel_time": 4159, "idunplug_station": 196, "ageRange": 5, "idplug_station": 147, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1653c"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 18, "user_type": 3, "idunplug_base": 18, "travel_time": 4310, "idunplug_station": 196, "ageRange": 5, "idplug_station": 147, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1653e"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 12, "user_type": 3, "idunplug_base": 17, "travel_time": 4349, "idunplug_station": 196, "ageRange": 5, "idplug_station": 147, "unplug_hourTime": "2020-03-13T00:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f1"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 9, "user_type": 3, "idunplug_base": 9, "travel_time": 12, "idunplug_station": 93, "ageRange": 5, "idplug_station": 93, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164f2"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 2, "user_type": 3, "idunplug_base": 8, "travel_time": 28, "idunplug_station": 93, "ageRange": 5, "idplug_station": 93, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff164fb"}, "user_day_code": "898c5103a500b4292a41d5c7a183e40e45347fd59da3429a3592ab3a642e5075", "idplug_base": 26, "user_type": 1, "idunplug_base": 8, "travel_time": 285, "idunplug_station": 58, "ageRange": 0, "idplug_station": 218, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff16503"}, "user_day_code": "15a06ed7c52f9618486b91733a297278bd1b4b7a6fe2adb92fbad028408bdbb3", "idplug_base": 9, "user_type": 1, "idunplug_base": 14, "travel_time": 536, "idunplug_station": 182, "ageRange": 0, "idplug_station": 83, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff16504"}, "user_day_code": "74d39dceb1cdc8762791fdb6e7c01e040e32db8cf75b5517d634a3d10a04b8ab", "idplug_base": 21, "user_type": 1, "idunplug_base": 3, "travel_time": 483, "idunplug_station": 7, "ageRange": 5, "idplug_station": 164, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28010"}\n',
#  '{"_id": {"$oid": "5eec831856bdeb043ff16505"}, "user_day_code": "13c224739c9353744e268252836eff55f7a8134f0ff8f1d19832061aab72b068", "idplug_base": 4, "user_type": 1, "idunplug_base": 7, "travel_time": 145, "idunplug_station": 27, "ageRange": 0, "idplug_station": 25, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16507"}, "user_day_code": "fd5478d465ed33658f5da4357a2d8e094b020bbf766b97a11b3766b91234c0ef", "idplug_base": 4, "user_type": 1, "idunplug_base": 19, "travel_time": 680, "idunplug_station": 12, "ageRange": 0, "idplug_station": 194, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16508"}, "user_day_code": "24856f5d9accc115d1cbbc3ef330a9d3f99292ad42c4c7ee87e6902404019f92", "idplug_base": 13, "user_type": 1, "idunplug_base": 23, "travel_time": 269, "idunplug_station": 143, "ageRange": 0, "idplug_station": 149, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1650b"}, "user_day_code": "885da84bc1d1989b03624901977e177a6789ed0b54ec68f96a3d2730c6442007", "idplug_base": 4, "user_type": 1, "idunplug_base": 6, "travel_time": 285, "idunplug_station": 36, "ageRange": 4, "idplug_station": 46, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1650c"}, "user_day_code": "edd74dbc7b564e9155185c24aefcaa8c344253ca5b075eba70e2d396b9a9bb93", "idplug_base": 13, "user_type": 1, "idunplug_base": 3, "travel_time": 631, "idunplug_station": 58, "ageRange": 4, "idplug_station": 75, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28009"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1650d"}, "user_day_code": "2d38333f9cc50a2b8ed20eade3beb14022ee3bdd8fc277d68b50316076c88183", "idplug_base": 11, "user_type": 1, "idunplug_base": 14, "travel_time": 266, "idunplug_station": 53, "ageRange": 3, "idplug_station": 184, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28008"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1650e"}, "user_day_code": "696c4172fd3a2180632cf60551fb59997b971c754e492030528de6f50b204929", "idplug_base": 22, "user_type": 1, "idunplug_base": 1, "travel_time": 726, "idunplug_station": 215, "ageRange": 0, "idplug_station": 208, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16510"}, "user_day_code": "dbace8ef9d1c8bb8a24c9b24a557996c04c50bd7e513a65c05d96a94931b3381", "idplug_base": 11, "user_type": 1, "idunplug_base": 7, "travel_time": 578, "idunplug_station": 25, "ageRange": 0, "idplug_station": 116, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16511"}, "user_day_code": "d37b596fb9f2df7ab933ef9dacc785eeb54cf12174fec6a972b62f62896cd1a2", "idplug_base": 23, "user_type": 1, "idunplug_base": 7, "travel_time": 746, "idunplug_station": 13, "ageRange": 0, "idplug_station": 195, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16514"}, "user_day_code": "284aae020d19429155c0aed6d9339a68a73717da54583998a96ec037a7c8915a", "idplug_base": 14, "user_type": 1, "idunplug_base": 8, "travel_time": 463, "idunplug_station": 157, "ageRange": 5, "idplug_station": 59, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28020"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16516"}, "user_day_code": "31a510fff73c76d8c5c3d2e2e0ef70929030e6749664bddd597638f5a944886e", "idplug_base": 4, "user_type": 1, "idunplug_base": 30, "travel_time": 475, "idunplug_station": 95, "ageRange": 0, "idplug_station": 87, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16518"}, "user_day_code": "35f66859d552d30b6c311a9fe67bc332228ca8af3e840aab92ed85cc345cf365", "idplug_base": 3, "user_type": 1, "idunplug_base": 1, "travel_time": 656, "idunplug_station": 131, "ageRange": 5, "idplug_station": 94, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28006"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16519"}, "user_day_code": "fcef9d32c87bdcff6ea472ac121e66db96335af01ad4b228d3fc784024facc12", "idplug_base": 22, "user_type": 1, "idunplug_base": 4, "travel_time": 275, "idunplug_station": 37, "ageRange": 4, "idplug_station": 46, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1651a"}, "user_day_code": "92b11ac41692c9d442308b93ff0045253360d3848b3cad5eaab8f4855fefdff5", "idplug_base": 4, "user_type": 1, "idunplug_base": 15, "travel_time": 828, "idunplug_station": 56, "ageRange": 0, "idplug_station": 210, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1651b"}, "user_day_code": "0d4f45cbf32632738cdcacff7f7d2cbe999cc223f73128c58519a6eeca16c8e3", "idplug_base": 3, "user_type": 1, "idunplug_base": 2, "travel_time": 468, "idunplug_station": 101, "ageRange": 0, "idplug_station": 124, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1651c"}, "user_day_code": "898c5103a500b4292a41d5c7a183e40e45347fd59da3429a3592ab3a642e5075", "idplug_base": 5, "user_type": 1, "idunplug_base": 8, "travel_time": 607, "idunplug_station": 60, "ageRange": 0, "idplug_station": 136, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1651d"}, "user_day_code": "55c99c37962c339d1122d920de4893615db85ec64f299de279b0662524db2d77", "idplug_base": 16, "user_type": 1, "idunplug_base": 21, "travel_time": 1190, "idunplug_station": 16, "ageRange": 0, "idplug_station": 179, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1651e"}, "user_day_code": "8029883078137fa53698a658e5ed953d7747d9d23b38aa2d65dc9bbc52a115b0", "idplug_base": 7, "user_type": 1, "idunplug_base": 7, "travel_time": 257, "idunplug_station": 187, "ageRange": 0, "idplug_station": 82, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1651f"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 24, "user_type": 3, "idunplug_base": 20, "travel_time": 1128, "idunplug_station": 93, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16520"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 20, "user_type": 3, "idunplug_base": 19, "travel_time": 1186, "idunplug_station": 93, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16521"}, "user_day_code": "1e1ad74287ed7b8cc8e9cdbc13efbebbc1aef8c95bccf568969a65fb6244e083", "idplug_base": 5, "user_type": 1, "idunplug_base": 18, "travel_time": 1146, "idunplug_station": 85, "ageRange": 5, "idplug_station": 63, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28004"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16522"}, "user_day_code": "462b15ff4e3c075e1917afeabaff01a2e13c3368229f3aa8d6e3b1ba71a7d50f", "idplug_base": 18, "user_type": 1, "idunplug_base": 10, "travel_time": 541, "idunplug_station": 154, "ageRange": 0, "idplug_station": 114, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16523"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 18, "user_type": 3, "idunplug_base": 13, "travel_time": 1537, "idunplug_station": 93, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16525"}, "user_day_code": "c8bb26409bf2a962063bb2d290cdb9b027f15e81dc272b7e41578bc45218c832", "idplug_base": 16, "user_type": 1, "idunplug_base": 20, "travel_time": 1565, "idunplug_station": 16, "ageRange": 5, "idplug_station": 127, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28045"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16526"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 16, "user_type": 3, "idunplug_base": 3, "travel_time": 1204, "idunplug_station": 93, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16527"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 12, "user_type": 3, "idunplug_base": 15, "travel_time": 1590, "idunplug_station": 93, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1652c"}, "user_day_code": "a87ee148a7b3075aee4016d68f0dce6a98172c6610d56ea5a83da87e8618b0e9", "idplug_base": 8, "user_type": 3, "idunplug_base": 17, "travel_time": 1607, "idunplug_station": 93, "ageRange": 5, "idplug_station": 211, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16531"}, "user_day_code": "50932ce58290447d7be34b1de5c6a045bc588ebc87522de8b8618632c47b61f3", "idplug_base": 4, "user_type": 1, "idunplug_base": 6, "travel_time": 1245, "idunplug_station": 71, "ageRange": 5, "idplug_station": 121, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28008"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16533"}, "user_day_code": "2ba61a291aa5e45a62f30a9f3c047fa5d584c278ebfb946c82b1c7b1ba8f3757", "idplug_base": 3, "user_type": 1, "idunplug_base": 4, "travel_time": 1230, "idunplug_station": 168, "ageRange": 0, "idplug_station": 38, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16534"}, "user_day_code": "ee0f04ddd2bbb107c5777e9361775f6f55ecb222b8e09419f45827a6948caef7", "idplug_base": 12, "user_type": 1, "idunplug_base": 1, "travel_time": 551, "idunplug_station": 81, "ageRange": 3, "idplug_station": 82, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16535"}, "user_day_code": "21e719b3a820d7c4f15052a6a0c9ed65cda85c11fbdd7920314cde2de8e6569e", "idplug_base": 3, "user_type": 1, "idunplug_base": 3, "travel_time": 697, "idunplug_station": 38, "ageRange": 0, "idplug_station": 185, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16536"}, "user_day_code": "c33c2c8e2098eb0dee31b5e0251b4232d435b8181d03ec194417e1db81983d32", "idplug_base": 7, "user_type": 1, "idunplug_base": 11, "travel_time": 1134, "idunplug_station": 189, "ageRange": 0, "idplug_station": 199, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16537"}, "user_day_code": "f9721b180833e62a37e8759e6a0bf49dc8abb194d8ec3b75494ee2de56e308b7", "idplug_base": 11, "user_type": 1, "idunplug_base": 9, "travel_time": 1660, "idunplug_station": 56, "ageRange": 0, "idplug_station": 57, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16538"}, "user_day_code": "dbc70690481548e5a673e421e86cb8785fd96296ab1b7bb54ce0f0207e578a7e", "idplug_base": 24, "user_type": 1, "idunplug_base": 6, "travel_time": 629, "idunplug_station": 6, "ageRange": 0, "idplug_station": 214, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16539"}, "user_day_code": "b4c67c4a902d7c1ae6f91a0102676416098492ed17402453ee2101ccad121a3c", "idplug_base": 9, "user_type": 1, "idunplug_base": 19, "travel_time": 800, "idunplug_station": 170, "ageRange": 4, "idplug_station": 197, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28027"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1653d"}, "user_day_code": "6ba661af39482b8f1e1ed7e1f9ea899200ef5c7cfefc8107f542471a90506c14", "idplug_base": 7, "user_type": 1, "idunplug_base": 4, "travel_time": 470, "idunplug_station": 48, "ageRange": 4, "idplug_station": 26, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff1653f"}, "user_day_code": "fde056a2cacd56f3b714f2514d8ab0516c7d1a82c9266b8f9e20be3e63a5e8f9", "idplug_base": 11, "user_type": 1, "idunplug_base": 21, "travel_time": 1155, "idunplug_station": 118, "ageRange": 5, "idplug_station": 204, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28005"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16540"}, "user_day_code": "ab8e5c31d6957465853001d99c20a5a62b7b44639766fd7225c0bb210973120d", "idplug_base": 1, "user_type": 1, "idunplug_base": 5, "travel_time": 712, "idunplug_station": 63, "ageRange": 0, "idplug_station": 175, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16541"}, "user_day_code": "acadc338721110c9df573310148950d567286a5a6da4e7d1f7baf75454025303", "idplug_base": 11, "user_type": 1, "idunplug_base": 8, "travel_time": 755, "idunplug_station": 50, "ageRange": 3, "idplug_station": 83, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16543"}, "user_day_code": "949ae898f1c7b73c510d09509a9453d5eceaaa1d2ee179c0bb5c29e5b7d6e30e", "idplug_base": 18, "user_type": 3, "idunplug_base": 13, "travel_time": 1382, "idunplug_station": 57, "ageRange": 1, "idplug_station": 29, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec831956bdeb043ff16544"}, "user_day_code": "c2c025264b2dc0af0d325b4adf32bb744a3d1208306b56527a6355e322b5eea2", "idplug_base": 2, "user_type": 3, "idunplug_base": 11, "travel_time": 1401, "idunplug_station": 57, "ageRange": 0, "idplug_station": 29, "unplug_hourTime": "2020-03-13T01:00:00Z", "zip_code": ""}\n',
# ...
#  '{"_id": {"$oid": "5eec832356bdeb043ff168f2"}, "user_day_code": "f23f7a6b8b0481ebba9d10ef4dde334ed0063dfa3e3943cfd96d38c4191b8390", "idplug_base": 23, "user_type": 1, "idunplug_base": 9, "travel_time": 813, "idunplug_station": 157, "ageRange": 0, "idplug_station": 33, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168f3"}, "user_day_code": "a9880df3c3fbf4cc637e27daa36139f6d1a0f0bdaa2def922a4c7b0d2373528b", "idplug_base": 11, "user_type": 1, "idunplug_base": 11, "travel_time": 551, "idunplug_station": 157, "ageRange": 4, "idplug_station": 93, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28003"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168f4"}, "user_day_code": "980883e3adf22c5e9ee91370ad677f5460fb1cd2a354f151ef5aaa56c6188bf1", "idplug_base": 7, "user_type": 1, "idunplug_base": 9, "travel_time": 538, "idunplug_station": 65, "ageRange": 5, "idplug_station": 73, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28009"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168f6"}, "user_day_code": "ec933fc2a50262b9c250163a53244092dd98ee80c5687c0e3092a19e5dbea329", "idplug_base": 2, "user_type": 1, "idunplug_base": 14, "travel_time": 944, "idunplug_station": 175, "ageRange": 0, "idplug_station": 167, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168f7"}, "user_day_code": "b1f5ad3a9f433639c77eb961badbb7cd19eb0f0414c4a9e91d4f7aa64e06b2ca", "idplug_base": 1, "user_type": 3, "idunplug_base": 1, "travel_time": 15, "idunplug_station": 177, "ageRange": 0, "idplug_station": 177, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168f8"}, "user_day_code": "2103b6189c48b7085b42effd620435a32a45bef8a7864a4c0e1e6183a83b248c", "idplug_base": 13, "user_type": 1, "idunplug_base": 7, "travel_time": 611, "idunplug_station": 149, "ageRange": 0, "idplug_station": 26, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168f9"}, "user_day_code": "eb27a6799c783a57910cb810d4135bf768056bd49dc48cdfafaf65e4a3759c95", "idplug_base": 1, "user_type": 1, "idunplug_base": 4, "travel_time": 1205, "idunplug_station": 48, "ageRange": 4, "idplug_station": 196, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168fa"}, "user_day_code": "42961256da47eb4f06241580e0b37c56e6f17e9a2012b09e3bd1dbe44de7a37a", "idplug_base": 23, "user_type": 1, "idunplug_base": 13, "travel_time": 1296, "idunplug_station": 181, "ageRange": 0, "idplug_station": 151, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168fb"}, "user_day_code": "1f5454d6cfcde6f44ff45d46a14af3c745046c3f390845dffc60aa4066c9b2af", "idplug_base": 23, "user_type": 1, "idunplug_base": 12, "travel_time": 744, "idunplug_station": 175, "ageRange": 4, "idplug_station": 163, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28011"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168fc"}, "user_day_code": "6ea20a3e2014c225a970adea374c0edc0715cd9d9f4e9d70fd911340e189dca7", "idplug_base": 5, "user_type": 1, "idunplug_base": 8, "travel_time": 699, "idunplug_station": 78, "ageRange": 5, "idplug_station": 130, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168fe"}, "user_day_code": "e451731c77914fc424dc0a67656d6b9551a0675984abbeb330c2ebc86e630586", "idplug_base": 6, "user_type": 1, "idunplug_base": 2, "travel_time": 804, "idunplug_station": 90, "ageRange": 5, "idplug_station": 134, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff168ff"}, "user_day_code": "1d3f51837b38f60ba5d5e24f090a8b74342ba535ec60ff759ad1cd5f93ade34c", "idplug_base": 13, "user_type": 1, "idunplug_base": 7, "travel_time": 1156, "idunplug_station": 53, "ageRange": 5, "idplug_station": 130, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16900"}, "user_day_code": "9533e14e47b810af5cc5773d1ae901831b3b43e7608ca310b57f28e6875958bc", "idplug_base": 23, "user_type": 1, "idunplug_base": 18, "travel_time": 384, "idunplug_station": 20, "ageRange": 4, "idplug_station": 167, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28004"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16901"}, "user_day_code": "2dac3e4b911beb97375d87dc33990c3e88cda608cfdcd1b14e3638ffdf6e5271", "idplug_base": 4, "user_type": 1, "idunplug_base": 22, "travel_time": 1096, "idunplug_station": 197, "ageRange": 0, "idplug_station": 44, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16902"}, "user_day_code": "1e8a8cef92e9abce787656b15c13c7ce6c092fc5eff3deadba9d6111dba54d94", "idplug_base": 5, "user_type": 1, "idunplug_base": 2, "travel_time": 533, "idunplug_station": 143, "ageRange": 5, "idplug_station": 165, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28020"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16903"}, "user_day_code": "88d98c4cf50bdb181fe8886e328fac65ee5262e8861d0f4a7be6cf4cb1dab966", "idplug_base": 23, "user_type": 1, "idunplug_base": 16, "travel_time": 1250, "idunplug_station": 59, "ageRange": 0, "idplug_station": 138, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16904"}, "user_day_code": "3591e7254a03df051dfd717763307207906593ac62fc5e72301ed376c7840aec", "idplug_base": 21, "user_type": 1, "idunplug_base": 14, "travel_time": 593, "idunplug_station": 59, "ageRange": 4, "idplug_station": 108, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28933"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16906"}, "user_day_code": "27c75f1ba6108611e62c3cce81c55b85e4b2e3e81cc2a8b6232c6594e1ddfa81", "idplug_base": 8, "user_type": 1, "idunplug_base": 22, "travel_time": 513, "idunplug_station": 106, "ageRange": 0, "idplug_station": 87, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16907"}, "user_day_code": "7db7485b77c79440380af9720c50a335205b20ad39ada1ee45689079c4df84e3", "idplug_base": 2, "user_type": 1, "idunplug_base": 22, "travel_time": 546, "idunplug_station": 30, "ageRange": 3, "idplug_station": 51, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16908"}, "user_day_code": "2ad3f3a8b0e1bfe8f550cca629ee23b85674f739e39c4c42d886d5627cca3a3d", "idplug_base": 6, "user_type": 1, "idunplug_base": 11, "travel_time": 571, "idunplug_station": 135, "ageRange": 5, "idplug_station": 49, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28045"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff16909"}, "user_day_code": "97fd44fd820203acd28b3dbf906d26ed09d6a357636b64c3afbc97a3e29b1b13", "idplug_base": 21, "user_type": 1, "idunplug_base": 6, "travel_time": 1721, "idunplug_station": 43, "ageRange": 5, "idplug_station": 216, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28005"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff1690a"}, "user_day_code": "4fa48ce6f1f8398c374835c0480e18d4e4bdebcbf32779184ffba74309ebd1f2", "idplug_base": 18, "user_type": 1, "idunplug_base": 6, "travel_time": 630, "idunplug_station": 216, "ageRange": 4, "idplug_station": 153, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28036"}\n',
#  '{"_id": {"$oid": "5eec832356bdeb043ff1690b"}, "user_day_code": "fca5bc9561677030e4445e93b698d3a6b7c7d8211978873593ed0fa0064638ec", "idplug_base": 18, "user_type": 1, "idunplug_base": 2, "travel_time": 680, "idunplug_station": 179, "ageRange": 5, "idplug_station": 28, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff1690d"}, "user_day_code": "45195618fe2fac87831d38cbfd1211235302ccc529b8854bf62d149f6e544e1d", "idplug_base": 7, "user_type": 1, "idunplug_base": 5, "travel_time": 732, "idunplug_station": 48, "ageRange": 4, "idplug_station": 124, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff1690e"}, "user_day_code": "915c7478409757d0215c7a9627f44bb13dbfbfe199e657463b94d8f6aae3a6ac", "idplug_base": 3, "user_type": 1, "idunplug_base": 19, "travel_time": 600, "idunplug_station": 109, "ageRange": 4, "idplug_station": 205, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16910"}, "user_day_code": "484b25d95db3ba7116568398250dc31340c29739b99cdb28c77ab3e372b70029", "idplug_base": 19, "user_type": 1, "idunplug_base": 24, "travel_time": 827, "idunplug_station": 26, "ageRange": 4, "idplug_station": 153, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28040"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16911"}, "user_day_code": "fc11c1d034596ff41bfae4ffec9e21112ef4be868a2ab5ab8c33fb18c30b0219", "idplug_base": 1, "user_type": 1, "idunplug_base": 16, "travel_time": 575, "idunplug_station": 163, "ageRange": 0, "idplug_station": 20, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16912"}, "user_day_code": "4311bf2743d3680f84411773a2cbacd282b467e4f2091d67940b6e52200694c7", "idplug_base": 7, "user_type": 1, "idunplug_base": 20, "travel_time": 1637, "idunplug_station": 77, "ageRange": 5, "idplug_station": 40, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16913"}, "user_day_code": "83f09799276b2d17a012c622d4bbe4c9400ad550c2dcfb9f83c350202a438f06", "idplug_base": 6, "user_type": 1, "idunplug_base": 10, "travel_time": 961, "idunplug_station": 199, "ageRange": 0, "idplug_station": 157, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16914"}, "user_day_code": "fc6c2c0675be99914cbff8dcd3639b16e5d6525e94c2405c121f0b6ad05fa08c", "idplug_base": 21, "user_type": 1, "idunplug_base": 3, "travel_time": 1481, "idunplug_station": 177, "ageRange": 5, "idplug_station": 65, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16915"}, "user_day_code": "84ad60851a4b59ae95fa818a73c18d92c529df794f190a8e471eecf9873d2e53", "idplug_base": 2, "user_type": 3, "idunplug_base": 2, "travel_time": 719, "idunplug_station": 151, "ageRange": 5, "idplug_station": 142, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16916"}, "user_day_code": "bc05697b04a3a54e24bec9f40a605f7af26ca6aaa6dcb5b73627e8ff0762b88f", "idplug_base": 22, "user_type": 1, "idunplug_base": 16, "travel_time": 482, "idunplug_station": 142, "ageRange": 5, "idplug_station": 172, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28016"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16917"}, "user_day_code": "228a8f7fe84ede1c8a9c6c502eeefe0fc413f9f4bf94f06d34ee4c36df15344c", "idplug_base": 4, "user_type": 1, "idunplug_base": 4, "travel_time": 649, "idunplug_station": 178, "ageRange": 3, "idplug_station": 69, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16918"}, "user_day_code": "0fc71e307114edfa44c1aa75185e8e08541348513106fe215207f275a3fa2277", "idplug_base": 4, "user_type": 1, "idunplug_base": 2, "travel_time": 1345, "idunplug_station": 126, "ageRange": 4, "idplug_station": 201, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28045"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16919"}, "user_day_code": "cf482a3ed5d3d00005a4e3510a3ab807ee3e7695749179638a3a519392ba9c54", "idplug_base": 11, "user_type": 1, "idunplug_base": 7, "travel_time": 697, "idunplug_station": 141, "ageRange": 3, "idplug_station": 98, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28003"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff1691a"}, "user_day_code": "84ad60851a4b59ae95fa818a73c18d92c529df794f190a8e471eecf9873d2e53", "idplug_base": 4, "user_type": 3, "idunplug_base": 3, "travel_time": 772, "idunplug_station": 151, "ageRange": 5, "idplug_station": 142, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff1691b"}, "user_day_code": "ffe1b5d7678e875962bc019baa17df8db04537f247bfc74437d0d18c43d7c115", "idplug_base": 1, "user_type": 1, "idunplug_base": 12, "travel_time": 185, "idunplug_station": 52, "ageRange": 5, "idplug_station": 57, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff1691c"}, "user_day_code": "84ad60851a4b59ae95fa818a73c18d92c529df794f190a8e471eecf9873d2e53", "idplug_base": 6, "user_type": 3, "idunplug_base": 15, "travel_time": 814, "idunplug_station": 151, "ageRange": 5, "idplug_station": 142, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff1691d"}, "user_day_code": "e5a2f17fdc8a03157d958cb9ddf0d73f130eb614345211bf4cb1f53431eb9072", "idplug_base": 24, "user_type": 1, "idunplug_base": 21, "travel_time": 561, "idunplug_station": 65, "ageRange": 5, "idplug_station": 198, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28009"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff1691f"}, "user_day_code": "011ae3c9802297c7c917318b6d4e115db520e9eed7df3aa26cd5aa4e35c11805", "idplug_base": 17, "user_type": 1, "idunplug_base": 9, "travel_time": 1337, "idunplug_station": 78, "ageRange": 5, "idplug_station": 125, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28007"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16920"}, "user_day_code": "84ad60851a4b59ae95fa818a73c18d92c529df794f190a8e471eecf9873d2e53", "idplug_base": 8, "user_type": 3, "idunplug_base": 14, "travel_time": 852, "idunplug_station": 151, "ageRange": 5, "idplug_station": 142, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16921"}, "user_day_code": "31ac9a18febb3b03bae353cd5db37357b19c99a441acbe0a5bf73150badf08db", "idplug_base": 5, "user_type": 1, "idunplug_base": 12, "travel_time": 548, "idunplug_station": 216, "ageRange": 5, "idplug_station": 152, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28026"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16922"}, "user_day_code": "fbf292632fd10b5f7d0e5359eae0c8667aac15291d6b567e9f8605a013025def", "idplug_base": 7, "user_type": 3, "idunplug_base": 1, "travel_time": 12, "idunplug_station": 177, "ageRange": 5, "idplug_station": 177, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16923"}, "user_day_code": "41d83ade81a5e07e97f5ceef7da171643c63d56c03877998dfc04843c8ed3fc8", "idplug_base": 2, "user_type": 1, "idunplug_base": 8, "travel_time": 816, "idunplug_station": 200, "ageRange": 0, "idplug_station": 21, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16924"}, "user_day_code": "2ed207b6b622494477a6561a42001638d177e3625a3520f7b2d7cdb2558e776f", "idplug_base": 17, "user_type": 1, "idunplug_base": 5, "travel_time": 605, "idunplug_station": 74, "ageRange": 4, "idplug_station": 198, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28009"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16925"}, "user_day_code": "e3744f9445b77b8070e8a54d14a04ad9c668b7d7099fc4355bfdb1555bb7b60d", "idplug_base": 21, "user_type": 1, "idunplug_base": 12, "travel_time": 618, "idunplug_station": 57, "ageRange": 4, "idplug_station": 175, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": "28012"}\n',
#  '{"_id": {"$oid": "5eec832456bdeb043ff16926"}, "user_day_code": "f33a8efba81d4ac5fb02704aaca3a398d50aa82f1bb72c613454bba58edc574b", "idplug_base": 10, "user_type": 3, "idunplug_base": 17, "travel_time": 1458, "idunplug_station": 198, "ageRange": 0, "idplug_station": 83, "unplug_hourTime": "2020-03-13T07:00:00Z", "zip_code": ""}\n',
#  ...]

# %%
rdd_semana = sc.parallelize(lista_json_semana)

# %% [markdown]
# Usos estaciones semana elegida

# %%
from datetime import datetime

def salidas(line):
  """
  Sacamos solo la fecha y las estaciones de salida y llegada.
  Y la clave será el par (fecha, estación de salida)
  """
  linea = json.loads(line)
  start = linea['idunplug_station']
  end = linea['idplug_station']
  date_ = linea['unplug_hourTime'][0:10]
  date = datetime.strptime(date_, '%Y-%m-%d').weekday()
  return (date, start), end

def llegadas(line):
  """
  Sacamos solo la fecha y las estaciones de salida y llegada.
  Y la clave será el par (fecha, estación de llegada)
  """
  linea = json.loads(line)
  start = linea['idunplug_station']
  end = linea['idplug_station']
  date_ = linea['unplug_hourTime'][0:10]
  date = datetime.strptime(date_, '%Y-%m-%d').weekday()
  return (date, end), start

# %%
line
# Out:
# '{"_id": {"$oid": "5eeca06d618046678f83b07a"}, "user_day_code": "a880483c5b4c4a773bd66e0a353ccb13bcf98c7a6605373bb7ee7f54ebe6b07c", "idplug_base": 8, "user_type": 3, "idunplug_base": 8, "travel_time": 7612873, "idunplug_station": 136, "ageRange": 5, "idplug_station": 108, "unplug_hourTime": "2020-03-17T18:00:00Z", "zip_code": "28022"}\n'

# %%
salidas(line)
# Out:
# ((1, 136), 108)

# %%
llegadas(line)
# Out:
# ((1, 108), 136)

# %%
viajes1 = rdd_semana.map(salidas).map(lambda x: (x[0], 1)).reduceByKey(add) 
lista1 = viajes1.collect()
lista_salidas = list(map(lambda x:[x[0][1],x[0][0],x[1]], lista1))  #lista con: estaciones salidas,día(del 0 al 6), estaciones llegadas


viajes2 = rdd_semana.map(llegadas).map(lambda x: (x[0], 1)).reduceByKey(add) 
lista2 = viajes2.collect()
lista_llegadas = list(map(lambda x:[x[0][1],x[0][0],x[1]], lista2)) #lista con: estaciones llegadas,día(del 0 al 6), estaciones salidas

salidas = rdd_semana.map(salidas)
viajes_totales = rdd_semana.map(llegadas).cogroup(salidas).map(lambda x: (x[0], len(list(x[1][0])) + len(list(x[1][1])) ) ).map(lambda x:((x[0][1],x[0][0]),x[1])) 
lista_totales = viajes_totales.collect()
viajes_totales_semana = sc.parallelize(lista_totales) #rdd de viajes totales,con salidas y llegadas

# %%
lista_salidas
# Out:
# [[35, 4, 19],
#  [143, 4, 20],
#  [13, 4, 48],
#  [60, 4, 21],
#  [107, 4, 16],
#  [114, 4, 36],
#  [59, 4, 63],
#  [30, 4, 48],
#  [163, 4, 84],
#  [150, 4, 17],
#  [9, 4, 52],
#  [39, 4, 14],
#  [27, 4, 30],
#  [109, 4, 17],
#  [162, 4, 45],
#  [95, 4, 52],
#  [10, 4, 25],
#  [195, 4, 21],
#  [134, 4, 39],
#  [124, 4, 21],
#  [21, 4, 35],
#  [87, 4, 23],
#  [89, 4, 37],
#  [62, 4, 57],
#  [122, 4, 27],
#  [19, 4, 56],
#  [96, 4, 36],
#  [57, 4, 112],
#  [189, 4, 53],
#  [48, 4, 58],
#  [115, 4, 34],
#  [50, 4, 47],
#  [81, 4, 49],
#  [202, 4, 33],
#  [90, 4, 72],
#  [161, 4, 72],
#  [63, 4, 26],
#  [142, 4, 38],
#  [157, 4, 58],
#  [16, 4, 32],
#  [77, 4, 49],
#  [206, 4, 21],
#  [207, 4, 38],
#  [192, 4, 32],
#  [91, 4, 47],
#  [113, 4, 36],
#  [45, 4, 69],
#  [179, 4, 36],
#  [128, 4, 69],
#  [133, 4, 38],
#  [82, 4, 43],
#  [187, 4, 72],
#  [185, 4, 66],
#  [197, 4, 33],
#  [196, 4, 28],
#  [93, 4, 24],
#  [58, 4, 54],
#  [182, 4, 52],
#  [7, 4, 23],
#  [12, 4, 24],
#  [36, 4, 18],
#  [53, 4, 72],
#  [215, 4, 18],
#  [25, 4, 22],
#  [131, 4, 52],
#  [37, 4, 27],
#  [56, 4, 34],
#  [101, 4, 32],
#  [85, 4, 22],
#  [154, 4, 28],
#  [71, 4, 27],
#  [168, 4, 73],
#  [38, 4, 59],
#  [6, 4, 47],
#  [170, 4, 51],
#  [118, 4, 33],
#  [42, 4, 38],
#  [169, 4, 59],
#  [217, 4, 16],
#  [79, 4, 63],
#  [78, 4, 42],
#  [5, 4, 27],
#  [116, 4, 15],
#  [3, 4, 48],
#  [75, 4, 38],
#  [160, 4, 83],
#  [149, 4, 93],
#  [209, 4, 25],
#  [18, 4, 42],
#  [213, 4, 48],
#  [219, 4, 45],
#  [140, 4, 33],
#  [129, 4, 56],
#  [117, 4, 22],
#  [83, 4, 70],
#  [43, 4, 74],
#  [130, 4, 30],
#  [198, 4, 51],
#  [171, 4, 36],
#  [205, 4, 18],
#  [47, 4, 23],
#  [155, 4, 23],
#  [126, 4, 37],
#  [74, 4, 47],
#  [204, 4, 54],
#  [80, 4, 30],
#  [51, 4, 35],
#  [177, 4, 54],
#  [49, 4, 63],
#  [180, 4, 29],
#  [69, 4, 25],
#  [174, 4, 21],
#  [105, 4, 16],
#  [110, 4, 28],
#  [214, 4, 26],
#  [178, 4, 38],
#  [86, 4, 30],
#  [136, 4, 43],
#  [210, 4, 32],
#  [54, 4, 26],
#  [26, 4, 49],
#  [99, 4, 34],
#  [41, 4, 86],
#  [186, 4, 27],
#  [8, 4, 32],
#  [208, 4, 90],
#  [201, 4, 24],
#  [44, 4, 36],
#  [212, 4, 40],
#  [76, 4, 33],
#  [148, 4, 26],
#  [106, 4, 34],
#  [175, 4, 96],
#  [4, 4, 20],
#  [216, 4, 30],
#  [181, 4, 56],
#  [138, 4, 28],
#  [137, 4, 33],
#  [191, 4, 15],
#  [139, 4, 52],
#  [84, 4, 42],
#  [40, 4, 20],
#  [17, 4, 48],
#  [188, 4, 28],
#  [46, 4, 54],
#  [108, 4, 50],
#  [156, 4, 24],
#  [52, 4, 43],
#  [102, 4, 24],
#  [145, 4, 47],
#  [127, 4, 26],
#  [65, 4, 77],
#  [184, 4, 46],
#  [14, 4, 45],
#  [172, 4, 44],
#  [193, 4, 17],
#  [211, 4, 23],
#  [132, 4, 68],
#  [34, 4, 29],
#  [125, 4, 36],
#  [199, 4, 40],
#  [176, 4, 29],
#  [203, 4, 16],
#  [55, 4, 49],
#  [200, 4, 32],
#  [123, 4, 41],
#  [67, 4, 41],
#  [94, 4, 35],
#  [31, 4, 39],
#  [183, 4, 64],
#  [121, 4, 24],
#  [194, 4, 14],
#  [20, 4, 33],
#  [190, 4, 23],
#  [88, 4, 18],
#  [73, 4, 36],
#  [92, 4, 22],
#  [141, 4, 26],
#  [33, 4, 23],
#  [153, 4, 27],
#  [166, 4, 29],
#  [28, 4, 17],
#  [64, 4, 48],
#  [151, 4, 19],
#  [158, 4, 31],
#  [100, 4, 19],
#  [11, 4, 22],
#  [72, 4, 14],
#  [135, 4, 84],
#  [164, 4, 49],
#  [97, 4, 18],
#  [144, 4, 11],
#  [15, 4, 19],
#  [159, 4, 18],
#  [120, 4, 9],
#  [173, 4, 7],
#  [61, 4, 12],
#  [167, 4, 21],
#  [119, 4, 11],
#  [146, 4, 18],
#  [2, 4, 14],
#  [165, 4, 14],
#  [218, 4, 19],
#  [104, 4, 15],
#  [1, 4, 23],
#  [98, 4, 12],
#  [103, 4, 28],
#  [29, 4, 12],
#  [111, 4, 10],
#  [152, 4, 9],
#  [147, 4, 8],
#  [112, 4, 5],
#  [190, 5, 7],
#  [19, 5, 22],
#  [133, 5, 8],
#  [10, 5, 8],
#  [101, 5, 8],
#  [219, 5, 15],
#  [212, 5, 16],
#  [197, 5, 21],
#  [170, 5, 12],
#  [161, 5, 25],
#  [163, 5, 27],
#  [18, 5, 16],
#  [67, 5, 14],
#  [26, 5, 17],
#  [139, 5, 26],
#  [123, 5, 10],
#  [56, 5, 20],
#  [37, 5, 15],
#  [57, 5, 43],
#  [189, 5, 13],
#  [75, 5, 13],
#  [12, 5, 9],
#  [199, 5, 16],
#  [4, 5, 13],
#  [49, 5, 35],
#  [187, 5, 26],
#  [128, 5, 20],
#  [42, 5, 12],
#  [208, 5, 37],
#  [131, 5, 20],
#  [192, 5, 13],
#  [71, 5, 14],
#  [149, 5, 28],
#  [126, 5, 6],
#  [175, 5, 59],
#  [147, 5, 5],
#  [38, 5, 21],
#  [3, 5, 2],
#  [135, 5, 32],
#  [65, 5, 27],
#  [143, 5, 7],
#  [45, 5, 26],
#  [13, 5, 20],
#  [95, 5, 9],
#  [84, 5, 16],
#  [11, 5, 3],
#  [43, 5, 50],
#  [157, 5, 19],
#  [41, 5, 18],
#  [168, 5, 16],
#  [216, 5, 6],
#  [83, 5, 23],
#  [213, 5, 22],
#  [180, 5, 19],
#  [186, 5, 5],
#  [52, 5, 20],
#  [5, 5, 16],
#  [185, 5, 21],
#  [118, 5, 11],
#  [48, 5, 14],
#  [148, 5, 8],
#  [202, 5, 12],
#  [210, 5, 4],
#  [206, 5, 4],
#  [218, 5, 9],
#  [176, 5, 15],
#  [178, 5, 10],
#  [150, 5, 8],
#  [82, 5, 14],
#  [160, 5, 18],
#  [9, 5, 12],
#  [129, 5, 23],
#  [51, 5, 9],
#  [81, 5, 12],
#  [137, 5, 6],
#  [120, 5, 11],
#  [114, 5, 11],
#  [59, 5, 24],
#  [74, 5, 19],
#  [106, 5, 12],
#  [34, 5, 15],
#  [177, 5, 18],
#  [130, 5, 16],
#  [141, 5, 9],
#  [55, 5, 24],
#  [110, 5, 6],
#  [108, 5, 10],
#  [17, 5, 15],
#  [20, 5, 6],
#  [31, 5, 14],
#  [169, 5, 21],
#  [174, 5, 7],
#  [156, 5, 9],
#  [183, 5, 17],
#  [195, 5, 9],
#  [191, 5, 2],
#  [125, 5, 12],
#  [44, 5, 17],
#  [164, 5, 14],
#  [122, 5, 15],
#  [136, 5, 11],
#  [90, 5, 25],
#  [207, 5, 19],
#  [39, 5, 6],
#  [53, 5, 16],
#  [127, 5, 10],
#  [62, 5, 14],
#  [80, 5, 14],
#  [89, 5, 10],
#  [132, 5, 47],
#  [76, 5, 14],
#  [54, 5, 7],
#  [124, 5, 9],
#  [201, 5, 11],
#  [214, 5, 14],
#  [91, 5, 9],
#  [194, 5, 8],
#  [85, 5, 9],
#  [204, 5, 12],
#  [79, 5, 19],
#  [142, 5, 4],
#  [166, 5, 13],
#  [215, 5, 10],
#  [6, 5, 18],
#  [188, 5, 4],
#  [94, 5, 10],
#  [146, 5, 4],
#  [103, 5, 16],
#  [162, 5, 7],
#  [198, 5, 12],
#  [184, 5, 17],
#  [72, 5, 5],
#  [93, 5, 3],
#  [196, 5, 11],
#  [8, 5, 9],
#  [78, 5, 16],
#  [16, 5, 10],
#  [217, 5, 4],
#  [121, 5, 9],
#  [21, 5, 6],
#  [153, 5, 11],
#  [182, 5, 15],
#  [47, 5, 14],
#  [107, 5, 4],
#  [46, 5, 28],
#  [193, 5, 6],
#  [15, 5, 5],
#  [77, 5, 13],
#  [117, 5, 11],
#  [134, 5, 20],
#  [7, 5, 6],
#  [200, 5, 6],
#  [86, 5, 14],
#  [113, 5, 9],
#  [172, 5, 19],
#  [145, 5, 7],
#  [92, 5, 10],
#  [30, 5, 5],
#  [14, 5, 10],
#  [64, 5, 16],
#  [25, 5, 6],
#  [211, 5, 8],
#  [40, 5, 6],
#  [205, 5, 4],
#  [63, 5, 14],
#  [96, 5, 10],
#  [104, 5, 12],
#  [69, 5, 8],
#  [36, 5, 8],
#  [58, 5, 21],
#  [119, 5, 7],
#  [111, 5, 1],
#  [181, 5, 8],
#  [87, 5, 11],
#  [97, 5, 4],
#  [73, 5, 20],
#  [179, 5, 7],
#  [61, 5, 5],
#  [159, 5, 8],
#  [138, 5, 5],
#  [27, 5, 8],
#  [35, 5, 7],
#  [154, 5, 8],
#  [50, 5, 9],
#  [158, 5, 7],
#  [171, 5, 8],
#  [203, 5, 6],
#  [155, 5, 9],
#  [140, 5, 3],
#  [28, 5, 3],
#  [99, 5, 5],
#  [1, 5, 5],
#  [102, 5, 6],
#  [152, 5, 14],
#  [33, 5, 3],
#  [116, 5, 7],
#  [209, 5, 3],
#  [173, 5, 3],
#  [165, 5, 2],
#  [60, 5, 2],
#  [98, 5, 3],
#  [29, 5, 3],
#  [2, 5, 3],
#  [115, 5, 3],
#  [105, 5, 2],
#  [167, 5, 2],
#  [144, 5, 3],
#  [88, 5, 1],
#  [210, 6, 2],
#  [27, 6, 1],
#  [138, 6, 1],
#  [25, 6, 2],
#  [215, 6, 5],
#  [99, 6, 1],
#  [114, 6, 3],
#  [165, 6, 2],
#  [31, 6, 11],
#  [9, 6, 4],
#  [203, 6, 3],
#  [206, 6, 3],
#  [192, 6, 2],
#  [187, 6, 8],
#  [51, 6, 3],
#  [93, 6, 1],
#  [13, 6, 10],
#  [59, 6, 22],
#  [212, 6, 6],
#  [163, 6, 15],
#  [197, 6, 3],
#  [44, 6, 9],
#  [185, 6, 4],
#  [90, 6, 5],
#  [11, 6, 4],
#  [177, 6, 6],
#  [141, 6, 7],
#  [218, 6, 7],
#  [81, 6, 12],
#  [137, 6, 14],
#  [107, 6, 4],
#  [195, 6, 6],
#  [135, 6, 8],
#  [172, 6, 7],
#  [168, 6, 6],
#  [213, 6, 16],
#  [14, 6, 4],
#  [148, 6, 8],
#  [161, 6, 4],
#  [131, 6, 10],
#  [26, 6, 5],
#  [132, 6, 6],
#  [50, 6, 4],
#  [56, 6, 4],
#  [169, 6, 4],
#  [79, 6, 8],
#  [166, 6, 3],
#  [170, 6, 7],
#  [219, 6, 4],
#  [155, 6, 13],
#  [150, 6, 7],
#  [111, 6, 1],
#  [200, 6, 1],
#  [74, 6, 5],
#  [164, 6, 12],
#  [106, 6, 5],
#  [116, 6, 2],
#  [175, 6, 20],
#  [57, 6, 13],
#  [183, 6, 9],
#  [180, 6, 4],
#  [196, 6, 4],
#  [186, 6, 2],
#  [157, 6, 6],
#  [97, 6, 1],
#  [38, 6, 7],
#  [20, 6, 5],
#  [62, 6, 9],
#  [52, 6, 4],
#  [17, 6, 10],
#  [33, 6, 1],
#  [18, 6, 12],
#  [75, 6, 23],
#  [156, 6, 2],
#  [86, 6, 8],
#  [149, 6, 16],
#  [189, 6, 3],
#  [84, 6, 5],
#  [136, 6, 5],
#  [42, 6, 5],
#  [55, 6, 8],
#  [179, 6, 8],
#  [92, 6, 1],
#  [147, 6, 7],
#  [39, 6, 1],
#  [7, 6, 7],
#  [76, 6, 28],
#  [208, 6, 10],
#  [160, 6, 10],
#  [49, 6, 13],
#  [12, 6, 4],
#  [46, 6, 6],
#  [124, 6, 2],
#  [82, 6, 5],
#  [48, 6, 8],
#  [123, 6, 7],
#  [139, 6, 10],
#  [67, 6, 30],
#  [173, 6, 3],
#  [214, 6, 9],
#  [65, 6, 13],
#  [110, 6, 3],
#  [129, 6, 7],
#  [204, 6, 6],
#  [5, 6, 5],
#  [94, 6, 6],
#  [198, 6, 3],
#  [80, 6, 6],
#  [4, 6, 7],
#  [45, 6, 7],
#  [201, 6, 11],
#  [184, 6, 3],
#  [30, 6, 5],
#  [71, 6, 3],
#  [73, 6, 4],
#  [19, 6, 10],
#  [118, 6, 10],
#  [134, 6, 4],
#  [209, 6, 3],
#  [207, 6, 4],
#  [122, 6, 2],
#  [41, 6, 6],
#  [89, 6, 4],
#  [117, 6, 5],
#  [102, 6, 4],
#  [190, 6, 3],
#  [15, 6, 3],
#  [28, 6, 2],
#  [34, 6, 4],
#  [96, 6, 4],
#  [83, 6, 5],
#  [133, 6, 9],
#  [145, 6, 5],
#  [10, 6, 3],
#  [216, 6, 5],
#  [103, 6, 6],
#  [142, 6, 14],
#  [171, 6, 3],
#  [16, 6, 5],
#  [205, 6, 2],
#  [154, 6, 6],
#  [194, 6, 2],
#  [104, 6, 2],
#  [78, 6, 2],
#  [120, 6, 1],
#  [6, 6, 8],
#  [43, 6, 7],
#  [178, 6, 2],
#  [72, 6, 2],
#  [158, 6, 4],
#  [85, 6, 4],
#  [87, 6, 1],
#  [128, 6, 5],
#  [63, 6, 8],
#  [143, 6, 3],
#  [130, 6, 4],
#  [53, 6, 3],
#  [113, 6, 3],
#  [174, 6, 5],
#  [191, 6, 1],
#  [153, 6, 3],
#  [95, 6, 6],
#  [108, 6, 3],
#  [77, 6, 2],
#  [125, 6, 2],
#  [1, 6, 3],
#  [182, 6, 2],
#  [162, 6, 4],
#  [21, 6, 2],
#  [54, 6, 4],
#  [181, 6, 5],
#  [58, 6, 5],
#  [98, 6, 1],
#  [140, 6, 11],
#  [101, 6, 2],
#  [167, 6, 1],
#  [119, 6, 2],
#  [2, 6, 1],
#  [69, 6, 1],
#  [127, 6, 10],
#  [217, 6, 9],
#  [115, 6, 2],
#  [202, 6, 3],
#  [151, 6, 1],
#  [64, 6, 4],
#  [3, 6, 3],
#  [199, 6, 3],
#  [121, 6, 2],
#  [29, 6, 2],
#  [211, 6, 2],
#  [100, 6, 1],
#  [8, 6, 5],
#  [40, 6, 2],
#  [35, 6, 1],
#  [126, 6, 1],
#  [37, 6, 3],
#  [91, 6, 1],
#  [144, 6, 1],
#  [188, 6, 1],
#  [60, 6, 1],
#  [138, 0, 3],
#  [37, 0, 1],
#  [204, 0, 3],
#  [139, 0, 5],
#  [148, 0, 3],
#  [146, 0, 2],
#  [173, 0, 5],
#  [205, 0, 1],
#  [159, 0, 3],
#  [153, 0, 1],
#  [149, 0, 1],
#  [156, 0, 2],
#  [213, 0, 1],
#  [151, 0, 1],
#  [144, 0, 1],
#  [161, 0, 3],
#  [150, 0, 2],
#  [210, 0, 9],
#  [162, 0, 2],
#  [152, 0, 6],
#  [211, 0, 2],
#  [155, 0, 3],
#  [203, 0, 1],
#  [93, 0, 2],
#  [212, 0, 2],
#  [202, 0, 1],
#  [110, 0, 1],
#  [167, 0, 3],
#  [108, 0, 2],
#  [198, 0, 1],
#  [109, 0, 2],
#  [208, 0, 4],
#  [171, 0, 2],
#  [160, 0, 2],
#  [118, 0, 1],
#  [166, 0, 1],
#  [112, 0, 2],
#  [117, 0, 1],
#  [111, 0, 2],
#  [99, 0, 1],
#  [199, 0, 1],
#  [196, 0, 3],
#  [170, 0, 4],
#  [95, 0, 2],
#  [200, 0, 4],
#  [113, 0, 3],
#  [206, 0, 2],
#  [201, 0, 2],
#  [101, 0, 3],
#  [168, 0, 1],
#  [195, 0, 2],
#  [69, 0, 1],
#  [197, 0, 2],
#  [193, 0, 2],
#  [77, 0, 4],
#  [114, 0, 3],
#  [76, 0, 3],
#  [131, 0, 3],
#  [61, 0, 2],
#  [105, 0, 4],
#  [106, 0, 2],
#  [207, 0, 5],
#  [87, 0, 2],
#  [81, 0, 5],
#  [192, 0, 3],
#  [190, 0, 2],
#  [65, 0, 1],
#  [90, 0, 3],
#  [104, 0, 5],
#  [74, 0, 3],
#  [79, 0, 1],
#  [103, 0, 3],
#  [83, 0, 4],
#  [78, 0, 4],
#  [189, 0, 3],
#  [67, 0, 2],
#  [96, 0, 3],
#  [75, 0, 4],
#  [194, 0, 27],
#  [107, 0, 9],
#  [94, 0, 6],
#  [88, 0, 6],
#  [98, 0, 3],
#  [191, 0, 1],
#  [72, 0, 3],
#  [73, 0, 2],
#  [80, 0, 1],
#  [91, 0, 2],
#  [86, 0, 1],
#  [85, 0, 3],
#  [119, 0, 6],
#  [116, 0, 7],
#  [164, 0, 1],
#  [132, 0, 7],
#  [34, 0, 1],
#  [40, 0, 3],
#  [27, 0, 2],
#  [120, 0, 5],
#  [169, 0, 2],
#  [125, 0, 1],
#  [9, 0, 3],
#  [121, 0, 1],
#  [130, 0, 1],
#  [26, 1, 3],
#  [4, 1, 2],
#  [5, 1, 2],
#  [6, 1, 1],
#  [58, 1, 1],
#  [17, 1, 1],
#  [13, 1, 1],
#  [21, 1, 3],
#  [122, 1, 3],
#  [123, 1, 2],
#  [15, 1, 1],
#  [14, 1, 1],
#  [11, 1, 3],
#  [62, 1, 4],
#  [7, 1, 1],
#  [30, 1, 1],
#  [124, 1, 2],
#  [175, 1, 2],
#  [84, 1, 6],
#  [174, 1, 2],
#  [8, 1, 2],
#  [177, 1, 2],
#  [3, 1, 2],
#  [18, 1, 1],
#  [187, 1, 4],
#  [1, 1, 9],
#  [2, 1, 5],
#  [82, 1, 2],
#  [16, 1, 1],
#  [218, 1, 3],
#  [133, 1, 1],
#  [28, 1, 1],
#  [46, 1, 2],
#  [10, 1, 2],
#  [50, 1, 3],
#  [134, 1, 2],
#  [35, 1, 2],
#  [37, 1, 2],
#  [59, 1, 2],
#  [39, 1, 1],
#  [219, 1, 2],
#  [45, 1, 1],
#  [29, 1, 2],
#  [38, 1, 1],
#  [127, 1, 5],
#  [43, 1, 2],
#  [54, 1, 2],
#  [55, 1, 3],
#  [31, 1, 2],
#  [129, 1, 1],
#  [135, 1, 3],
#  [52, 1, 1],
#  [180, 1, 1],
#  [51, 1, 4],
#  [126, 1, 4],
#  [178, 1, 2],
#  [182, 1, 4],
#  [184, 1, 6],
#  [57, 1, 3],
#  [185, 1, 4],
#  [142, 1, 1],
#  [181, 1, 2],
#  [183, 1, 3],
#  [48, 1, 4],
#  [136, 1, 9]]

# %%
lista_llegadas
# Out:
# [[16, 4, 26],
#  [142, 4, 44],
#  [218, 4, 21],
#  [132, 4, 67],
#  [19, 4, 60],
#  [206, 4, 25],
#  [203, 4, 27],
#  [168, 4, 69],
#  [213, 4, 43],
#  [143, 4, 22],
#  [106, 4, 38],
#  [215, 4, 16],
#  [47, 4, 23],
#  [122, 4, 26],
#  [21, 4, 36],
#  [56, 4, 32],
#  [197, 4, 36],
#  [13, 4, 48],
#  [187, 4, 69],
#  [175, 4, 101],
#  [115, 4, 42],
#  [130, 4, 30],
#  [15, 4, 18],
#  [183, 4, 64],
#  [139, 4, 58],
#  [82, 4, 39],
#  [196, 4, 24],
#  [89, 4, 26],
#  [88, 4, 8],
#  [35, 4, 19],
#  [7, 4, 20],
#  [199, 4, 33],
#  [83, 4, 61],
#  [91, 4, 52],
#  [57, 4, 107],
#  [128, 4, 63],
#  [174, 4, 13],
#  [81, 4, 47],
#  [51, 4, 32],
#  [177, 4, 56],
#  [43, 4, 77],
#  [149, 4, 85],
#  [216, 4, 26],
#  [181, 4, 54],
#  [207, 4, 45],
#  [135, 4, 90],
#  [49, 4, 60],
#  [125, 4, 35],
#  [200, 4, 32],
#  [102, 4, 31],
#  [117, 4, 22],
#  [189, 4, 53],
#  [80, 4, 33],
#  [170, 4, 57],
#  [185, 4, 60],
#  [76, 4, 32],
#  [95, 4, 57],
#  [164, 4, 53],
#  [217, 4, 16],
#  [211, 4, 27],
#  [147, 4, 15],
#  [93, 4, 21],
#  [25, 4, 25],
#  [194, 4, 19],
#  [46, 4, 50],
#  [75, 4, 34],
#  [184, 4, 48],
#  [208, 4, 93],
#  [116, 4, 19],
#  [195, 4, 18],
#  [59, 4, 65],
#  [87, 4, 20],
#  [94, 4, 38],
#  [210, 4, 20],
#  [124, 4, 22],
#  [136, 4, 34],
#  [179, 4, 30],
#  [63, 4, 28],
#  [114, 4, 39],
#  [127, 4, 30],
#  [121, 4, 24],
#  [38, 4, 50],
#  [214, 4, 30],
#  [26, 4, 55],
#  [204, 4, 49],
#  [29, 4, 18],
#  [79, 4, 59],
#  [28, 4, 19],
#  [131, 4, 42],
#  [62, 4, 61],
#  [172, 4, 40],
#  [153, 4, 27],
#  [18, 4, 42],
#  [166, 4, 32],
#  [105, 4, 12],
#  [20, 4, 35],
#  [48, 4, 46],
#  [169, 4, 57],
#  [209, 4, 27],
#  [58, 4, 50],
#  [52, 4, 48],
#  [65, 4, 74],
#  [171, 4, 29],
#  [133, 4, 36],
#  [120, 4, 14],
#  [8, 4, 25],
#  [11, 4, 30],
#  [176, 4, 26],
#  [50, 4, 40],
#  [190, 4, 24],
#  [84, 4, 42],
#  [64, 4, 61],
#  [30, 4, 46],
#  [86, 4, 31],
#  [14, 4, 35],
#  [212, 4, 34],
#  [55, 4, 51],
#  [154, 4, 26],
#  [27, 4, 19],
#  [44, 4, 33],
#  [37, 4, 29],
#  [17, 4, 44],
#  [109, 4, 22],
#  [145, 4, 55],
#  [31, 4, 46],
#  [151, 4, 11],
#  [85, 4, 25],
#  [71, 4, 28],
#  [157, 4, 61],
#  [118, 4, 36],
#  [3, 4, 45],
#  [162, 4, 52],
#  [78, 4, 36],
#  [41, 4, 77],
#  [202, 4, 30],
#  [146, 4, 14],
#  [5, 4, 20],
#  [36, 4, 19],
#  [160, 4, 72],
#  [42, 4, 44],
#  [123, 4, 44],
#  [97, 4, 19],
#  [98, 4, 12],
#  [6, 4, 46],
#  [219, 4, 53],
#  [113, 4, 40],
#  [99, 4, 30],
#  [148, 4, 23],
#  [180, 4, 30],
#  [90, 4, 67],
#  [103, 4, 45],
#  [33, 4, 20],
#  [67, 4, 46],
#  [163, 4, 77],
#  [10, 4, 34],
#  [201, 4, 31],
#  [104, 4, 12],
#  [126, 4, 35],
#  [101, 4, 22],
#  [39, 4, 14],
#  [108, 4, 56],
#  [159, 4, 11],
#  [161, 4, 71],
#  [198, 4, 50],
#  [4, 4, 27],
#  [112, 4, 12],
#  [45, 4, 73],
#  [72, 4, 14],
#  [158, 4, 28],
#  [60, 4, 19],
#  [74, 4, 43],
#  [96, 4, 32],
#  [53, 4, 57],
#  [100, 4, 17],
#  [182, 4, 50],
#  [192, 4, 35],
#  [152, 4, 19],
#  [165, 4, 24],
#  [134, 4, 34],
#  [92, 4, 23],
#  [167, 4, 26],
#  [34, 4, 25],
#  [138, 4, 27],
#  [1, 4, 33],
#  [155, 4, 22],
#  [9, 4, 52],
#  [150, 4, 13],
#  [140, 4, 38],
#  [144, 4, 11],
#  [40, 4, 31],
#  [2, 4, 23],
#  [191, 4, 22],
#  [77, 4, 44],
#  [141, 4, 29],
#  [61, 4, 16],
#  [129, 4, 54],
#  [54, 4, 29],
#  [178, 4, 35],
#  [156, 4, 25],
#  [193, 4, 13],
#  [111, 4, 21],
#  [69, 4, 28],
#  [110, 4, 35],
#  [188, 4, 24],
#  [137, 4, 33],
#  [73, 4, 33],
#  [205, 4, 18],
#  [186, 4, 24],
#  [107, 4, 22],
#  [119, 4, 19],
#  [173, 4, 11],
#  [12, 4, 23],
#  [115, 5, 5],
#  [41, 5, 17],
#  [42, 5, 11],
#  [134, 5, 21],
#  [166, 5, 11],
#  [163, 5, 26],
#  [203, 5, 6],
#  [168, 5, 22],
#  [65, 5, 37],
#  [211, 5, 8],
#  [114, 5, 19],
#  [90, 5, 33],
#  [175, 5, 56],
#  [71, 5, 14],
#  [76, 5, 11],
#  [198, 5, 13],
#  [80, 5, 13],
#  [47, 5, 13],
#  [132, 5, 52],
#  [49, 5, 28],
#  [57, 5, 41],
#  [200, 5, 7],
#  [43, 5, 36],
#  [189, 5, 15],
#  [216, 5, 8],
#  [199, 5, 16],
#  [157, 5, 15],
#  [176, 5, 10],
#  [187, 5, 24],
#  [170, 5, 19],
#  [53, 5, 21],
#  [83, 5, 25],
#  [18, 5, 20],
#  [19, 5, 15],
#  [121, 5, 8],
#  [9, 5, 16],
#  [130, 5, 20],
#  [147, 5, 5],
#  [75, 5, 13],
#  [149, 5, 31],
#  [143, 5, 10],
#  [169, 5, 22],
#  [183, 5, 20],
#  [62, 5, 17],
#  [195, 5, 11],
#  [63, 5, 12],
#  [193, 5, 5],
#  [12, 5, 11],
#  [84, 5, 16],
#  [184, 5, 7],
#  [214, 5, 13],
#  [212, 5, 20],
#  [89, 5, 13],
#  [209, 5, 4],
#  [20, 5, 11],
#  [118, 5, 11],
#  [217, 5, 11],
#  [153, 5, 11],
#  [116, 5, 15],
#  [8, 5, 17],
#  [208, 5, 36],
#  [156, 5, 9],
#  [50, 5, 11],
#  [178, 5, 7],
#  [91, 5, 6],
#  [135, 5, 29],
#  [56, 5, 16],
#  [87, 5, 9],
#  [204, 5, 15],
#  [26, 5, 20],
#  [82, 5, 13],
#  [3, 5, 7],
#  [31, 5, 18],
#  [7, 5, 10],
#  [86, 5, 16],
#  [123, 5, 6],
#  [79, 5, 15],
#  [213, 5, 20],
#  [159, 5, 9],
#  [172, 5, 16],
#  [93, 5, 4],
#  [44, 5, 20],
#  [202, 5, 9],
#  [33, 5, 1],
#  [154, 5, 14],
#  [215, 5, 12],
#  [180, 5, 19],
#  [131, 5, 24],
#  [30, 5, 5],
#  [17, 5, 16],
#  [35, 5, 5],
#  [74, 5, 22],
#  [85, 5, 5],
#  [188, 5, 6],
#  [160, 5, 24],
#  [181, 5, 7],
#  [138, 5, 5],
#  [190, 5, 7],
#  [122, 5, 20],
#  [139, 5, 19],
#  [207, 5, 10],
#  [25, 5, 8],
#  [37, 5, 17],
#  [34, 5, 17],
#  [219, 5, 12],
#  [151, 5, 3],
#  [59, 5, 17],
#  [67, 5, 14],
#  [6, 5, 15],
#  [117, 5, 10],
#  [1, 5, 6],
#  [5, 5, 14],
#  [54, 5, 12],
#  [64, 5, 15],
#  [38, 5, 19],
#  [146, 5, 3],
#  [95, 5, 12],
#  [164, 5, 19],
#  [182, 5, 12],
#  [96, 5, 9],
#  [69, 5, 10],
#  [92, 5, 10],
#  [81, 5, 10],
#  [107, 5, 5],
#  [161, 5, 26],
#  [60, 5, 8],
#  [162, 5, 8],
#  [197, 5, 15],
#  [77, 5, 13],
#  [101, 5, 7],
#  [133, 5, 6],
#  [136, 5, 16],
#  [177, 5, 18],
#  [106, 5, 9],
#  [185, 5, 21],
#  [58, 5, 20],
#  [55, 5, 15],
#  [78, 5, 13],
#  [128, 5, 22],
#  [45, 5, 22],
#  [125, 5, 8],
#  [103, 5, 12],
#  [129, 5, 18],
#  [206, 5, 3],
#  [94, 5, 8],
#  [16, 5, 10],
#  [46, 5, 23],
#  [111, 5, 1],
#  [52, 5, 15],
#  [13, 5, 15],
#  [120, 5, 7],
#  [142, 5, 8],
#  [205, 5, 5],
#  [15, 5, 6],
#  [108, 5, 5],
#  [14, 5, 11],
#  [140, 5, 2],
#  [11, 5, 1],
#  [21, 5, 11],
#  [102, 5, 2],
#  [29, 5, 5],
#  [27, 5, 17],
#  [97, 5, 6],
#  [192, 5, 13],
#  [73, 5, 24],
#  [167, 5, 3],
#  [110, 5, 4],
#  [155, 5, 9],
#  [104, 5, 11],
#  [119, 5, 12],
#  [39, 5, 4],
#  [113, 5, 7],
#  [174, 5, 5],
#  [171, 5, 6],
#  [201, 5, 12],
#  [127, 5, 16],
#  [36, 5, 3],
#  [194, 5, 5],
#  [196, 5, 11],
#  [186, 5, 5],
#  [126, 5, 2],
#  [210, 5, 3],
#  [179, 5, 10],
#  [109, 5, 1],
#  [218, 5, 8],
#  [173, 5, 4],
#  [4, 5, 10],
#  [165, 5, 3],
#  [48, 5, 18],
#  [105, 5, 3],
#  [150, 5, 6],
#  [137, 5, 10],
#  [61, 5, 5],
#  [98, 5, 3],
#  [88, 5, 1],
#  [112, 5, 1],
#  [51, 5, 6],
#  [124, 5, 6],
#  [10, 5, 6],
#  [148, 5, 4],
#  [40, 5, 7],
#  [72, 5, 8],
#  [99, 5, 4],
#  [141, 5, 6],
#  [100, 5, 3],
#  [144, 5, 2],
#  [158, 5, 12],
#  [145, 5, 6],
#  [152, 5, 4],
#  [2, 5, 2],
#  [29, 6, 2],
#  [41, 6, 8],
#  [157, 6, 11],
#  [132, 6, 7],
#  [219, 6, 6],
#  [149, 6, 15],
#  [218, 6, 8],
#  [207, 6, 4],
#  [121, 6, 3],
#  [169, 6, 8],
#  [63, 6, 7],
#  [206, 6, 1],
#  [168, 6, 10],
#  [136, 6, 7],
#  [117, 6, 6],
#  [130, 6, 2],
#  [60, 6, 2],
#  [215, 6, 2],
#  [197, 6, 4],
#  [172, 6, 5],
#  [128, 6, 7],
#  [195, 6, 6],
#  [184, 6, 2],
#  [75, 6, 24],
#  [135, 6, 10],
#  [77, 6, 6],
#  [142, 6, 5],
#  [123, 6, 4],
#  [4, 6, 7],
#  [134, 6, 6],
#  [54, 6, 4],
#  [26, 6, 18],
#  [212, 6, 7],
#  [209, 6, 2],
#  [131, 6, 12],
#  [139, 6, 11],
#  [194, 6, 5],
#  [160, 6, 12],
#  [76, 6, 29],
#  [18, 6, 7],
#  [25, 6, 3],
#  [174, 6, 5],
#  [84, 6, 8],
#  [163, 6, 11],
#  [39, 6, 3],
#  [85, 6, 8],
#  [166, 6, 3],
#  [170, 6, 8],
#  [155, 6, 8],
#  [111, 6, 2],
#  [200, 6, 1],
#  [91, 6, 3],
#  [44, 6, 7],
#  [204, 6, 10],
#  [103, 6, 8],
#  [57, 6, 18],
#  [10, 6, 4],
#  [180, 6, 3],
#  [33, 6, 3],
#  [31, 6, 6],
#  [126, 6, 2],
#  [199, 6, 5],
#  [2, 6, 4],
#  [181, 6, 3],
#  [62, 6, 8],
#  [20, 6, 2],
#  [65, 6, 8],
#  [156, 6, 3],
#  [83, 6, 8],
#  [49, 6, 13],
#  [115, 6, 3],
#  [74, 6, 5],
#  [45, 6, 8],
#  [59, 6, 19],
#  [202, 6, 3],
#  [90, 6, 8],
#  [179, 6, 11],
#  [173, 6, 4],
#  [86, 6, 4],
#  [37, 6, 7],
#  [127, 6, 2],
#  [34, 6, 5],
#  [55, 6, 7],
#  [190, 6, 4],
#  [95, 6, 5],
#  [175, 6, 17],
#  [67, 6, 29],
#  [189, 6, 5],
#  [64, 6, 3],
#  [15, 6, 3],
#  [13, 6, 8],
#  [51, 6, 3],
#  [94, 6, 4],
#  [81, 6, 11],
#  [162, 6, 3],
#  [198, 6, 3],
#  [116, 6, 1],
#  [110, 6, 4],
#  [148, 6, 8],
#  [82, 6, 2],
#  [48, 6, 11],
#  [92, 6, 2],
#  [143, 6, 4],
#  [30, 6, 4],
#  [38, 6, 9],
#  [28, 6, 2],
#  [106, 6, 5],
#  [208, 6, 12],
#  [17, 6, 8],
#  [176, 6, 2],
#  [217, 6, 6],
#  [71, 6, 3],
#  [185, 6, 2],
#  [6, 6, 7],
#  [89, 6, 4],
#  [164, 6, 13],
#  [5, 6, 9],
#  [177, 6, 5],
#  [46, 6, 7],
#  [133, 6, 10],
#  [114, 6, 6],
#  [154, 6, 5],
#  [88, 6, 2],
#  [102, 6, 2],
#  [19, 6, 8],
#  [183, 6, 10],
#  [196, 6, 2],
#  [47, 6, 1],
#  [187, 6, 9],
#  [58, 6, 7],
#  [171, 6, 4],
#  [178, 6, 6],
#  [73, 6, 2],
#  [53, 6, 4],
#  [16, 6, 4],
#  [145, 6, 7],
#  [150, 6, 2],
#  [104, 6, 2],
#  [56, 6, 7],
#  [211, 6, 2],
#  [213, 6, 17],
#  [97, 6, 1],
#  [9, 6, 3],
#  [52, 6, 2],
#  [80, 6, 1],
#  [210, 6, 8],
#  [107, 6, 5],
#  [72, 6, 2],
#  [192, 6, 2],
#  [1, 6, 3],
#  [216, 6, 7],
#  [153, 6, 3],
#  [182, 6, 4],
#  [79, 6, 4],
#  [137, 6, 1],
#  [124, 6, 2],
#  [118, 6, 6],
#  [3, 6, 3],
#  [138, 6, 1],
#  [12, 6, 1],
#  [35, 6, 4],
#  [193, 6, 3],
#  [201, 6, 4],
#  [96, 6, 11],
#  [43, 6, 8],
#  [214, 6, 5],
#  [186, 6, 2],
#  [158, 6, 3],
#  [129, 6, 9],
#  [50, 6, 1],
#  [21, 6, 2],
#  [122, 6, 1],
#  [125, 6, 3],
#  [120, 6, 1],
#  [98, 6, 1],
#  [93, 6, 1],
#  [14, 6, 11],
#  [152, 6, 1],
#  [141, 6, 3],
#  [161, 6, 4],
#  [69, 6, 1],
#  [87, 6, 5],
#  [11, 6, 4],
#  [7, 6, 10],
#  [147, 6, 1],
#  [42, 6, 4],
#  [188, 6, 1],
#  [203, 6, 1],
#  [8, 6, 6],
#  [40, 6, 4],
#  [191, 6, 1],
#  [113, 6, 1],
#  [146, 6, 2],
#  [108, 6, 1],
#  [36, 6, 2],
#  [140, 6, 2],
#  [138, 0, 1],
#  [57, 0, 3],
#  [1, 0, 4],
#  [2, 0, 1],
#  [28, 0, 4],
#  [40, 0, 5],
#  [14, 0, 2],
#  [29, 0, 3],
#  [16, 0, 2],
#  [35, 0, 1],
#  [67, 0, 2],
#  [165, 0, 1],
#  [142, 0, 4],
#  [205, 0, 1],
#  [143, 0, 1],
#  [20, 0, 4],
#  [10, 0, 6],
#  [33, 0, 1],
#  [160, 0, 4],
#  [209, 0, 1],
#  [154, 0, 1],
#  [134, 0, 2],
#  [159, 0, 4],
#  [153, 0, 3],
#  [149, 0, 2],
#  [156, 0, 1],
#  [7, 0, 2],
#  [93, 0, 1],
#  [151, 0, 3],
#  [144, 0, 2],
#  [37, 0, 2],
#  [27, 0, 3],
#  [140, 0, 2],
#  [210, 0, 4],
#  [162, 0, 1],
#  [18, 0, 2],
#  [219, 0, 1],
#  [41, 0, 2],
#  [49, 0, 2],
#  [52, 0, 3],
#  [39, 0, 2],
#  [69, 0, 2],
#  [34, 0, 4],
#  [173, 0, 1],
#  [85, 0, 1],
#  [177, 0, 5],
#  [212, 0, 1],
#  [180, 0, 2],
#  [117, 0, 4],
#  [31, 0, 2],
#  [147, 0, 2],
#  [109, 0, 1],
#  [118, 0, 2],
#  [206, 0, 5],
#  [3, 0, 3],
#  [100, 0, 2],
#  [77, 0, 5],
#  [194, 0, 27],
#  [80, 0, 1],
#  [43, 0, 2],
#  [112, 0, 1],
#  [196, 0, 2],
#  [170, 0, 1],
#  [95, 0, 2],
#  [208, 0, 2],
#  [58, 0, 1],
#  [4, 0, 1],
#  [30, 0, 3],
#  [47, 0, 1],
#  [150, 0, 1],
#  [25, 0, 2],
#  [97, 0, 5],
#  [104, 0, 3],
#  [107, 0, 5],
#  [158, 0, 2],
#  [56, 0, 1],
#  [84, 0, 2],
#  [201, 0, 2],
#  [101, 0, 2],
#  [197, 0, 2],
#  [108, 0, 2],
#  [114, 0, 2],
#  [204, 0, 1],
#  [169, 0, 1],
#  [125, 0, 1],
#  [11, 0, 2],
#  [9, 0, 5],
#  [63, 0, 1],
#  [38, 0, 3],
#  [207, 0, 1],
#  [115, 0, 3],
#  [81, 0, 3],
#  [111, 0, 1],
#  [203, 0, 1],
#  [145, 0, 1],
#  [8, 0, 1],
#  [96, 0, 1],
#  [178, 0, 1],
#  [51, 0, 3],
#  [90, 0, 2],
#  [74, 0, 1],
#  [79, 0, 1],
#  [103, 0, 2],
#  [83, 0, 4],
#  [163, 0, 1],
#  [13, 0, 1],
#  [46, 0, 1],
#  [87, 0, 1],
#  [130, 0, 1],
#  [75, 0, 1],
#  [94, 0, 2],
#  [133, 0, 6],
#  [48, 0, 1],
#  [110, 0, 3],
#  [214, 0, 1],
#  [5, 0, 2],
#  [26, 0, 2],
#  [216, 0, 4],
#  [98, 0, 3],
#  [191, 0, 2],
#  [128, 0, 1],
#  [91, 0, 1],
#  [86, 0, 1],
#  [164, 0, 1],
#  [121, 0, 1],
#  [119, 0, 2],
#  [120, 0, 1],
#  [195, 0, 2],
#  [132, 0, 1],
#  [171, 0, 1],
#  [192, 0, 1],
#  [213, 0, 1],
#  [55, 0, 2],
#  [26, 1, 4],
#  [116, 1, 2],
#  [201, 1, 3],
#  [12, 1, 2],
#  [5, 1, 2],
#  [95, 1, 1],
#  [166, 1, 1],
#  [170, 1, 3],
#  [90, 1, 2],
#  [139, 1, 1],
#  [21, 1, 1],
#  [147, 1, 3],
#  [44, 1, 2],
#  [162, 1, 1],
#  [120, 1, 2],
#  [154, 1, 2],
#  [51, 1, 11],
#  [177, 1, 4],
#  [153, 1, 1],
#  [11, 1, 3],
#  [62, 1, 2],
#  [200, 1, 1],
#  [214, 1, 1],
#  [61, 1, 3],
#  [183, 1, 1],
#  [124, 1, 2],
#  [175, 1, 1],
#  [84, 1, 1],
#  [93, 1, 1],
#  [73, 1, 1],
#  [72, 1, 1],
#  [34, 1, 3],
#  [164, 1, 1],
#  [108, 1, 4],
#  [103, 1, 1],
#  [161, 1, 1],
#  [192, 1, 3],
#  [144, 1, 2],
#  [128, 1, 1],
#  [187, 1, 2],
#  [216, 1, 2],
#  [133, 1, 1],
#  [38, 1, 1],
#  [40, 1, 2],
#  [210, 1, 2],
#  [160, 1, 3],
#  [55, 1, 4],
#  [176, 1, 1],
#  [135, 1, 3],
#  [171, 1, 2],
#  [28, 1, 1],
#  [46, 1, 1],
#  [151, 1, 1],
#  [27, 1, 1],
#  [155, 1, 1],
#  [213, 1, 1],
#  [119, 1, 1],
#  [142, 1, 1],
#  [45, 1, 1],
#  [64, 1, 3],
#  [91, 1, 4],
#  [54, 1, 3],
#  [43, 1, 2],
#  [31, 1, 2],
#  [129, 1, 1],
#  [81, 1, 1],
#  [202, 1, 1],
#  [52, 1, 1],
#  [180, 1, 1],
#  [78, 1, 1],
#  [79, 1, 2],
#  [136, 1, 7],
#  [189, 1, 1],
#  [149, 1, 1],
#  [182, 1, 1],
#  [184, 1, 2],
#  [74, 1, 1],
#  [152, 1, 1],
#  [185, 1, 1],
#  [37, 1, 4],
#  [69, 1, 1],
#  [198, 1, 1],
#  [118, 1, 1],
#  [16, 1, 1],
#  [67, 1, 1],
#  [80, 1, 1],
#  [36, 1, 1],
#  [117, 1, 1]]

# %%
lista_totales
# Out:
# [((16, 4), 58),
#  ((142, 4), 82),
#  ((218, 4), 40),
#  ((132, 4), 135),
#  ((206, 4), 46),
#  ((168, 4), 142),
#  ((106, 4), 72),
#  ((122, 4), 53),
#  ((56, 4), 66),
#  ((130, 4), 60),
#  ((82, 4), 82),
#  ((196, 4), 52),
#  ((88, 4), 26),
#  ((128, 4), 132),
#  ((174, 4), 34),
#  ((216, 4), 56),
#  ((200, 4), 64),
#  ((102, 4), 55),
#  ((80, 4), 63),
#  ((170, 4), 108),
#  ((76, 4), 65),
#  ((164, 4), 102),
#  ((194, 4), 33),
#  ((46, 4), 104),
#  ((184, 4), 94),
#  ((208, 4), 183),
#  ((116, 4), 34),
#  ((94, 4), 73),
#  ((210, 4), 52),
#  ((124, 4), 43),
#  ((136, 4), 77),
#  ((114, 4), 75),
#  ((38, 4), 109),
#  ((214, 4), 56),
#  ((26, 4), 104),
#  ((204, 4), 103),
#  ((28, 4), 36),
#  ((62, 4), 118),
#  ((172, 4), 84),
#  ((18, 4), 84),
#  ((166, 4), 61),
#  ((20, 4), 68),
#  ((48, 4), 104),
#  ((58, 4), 104),
#  ((52, 4), 91),
#  ((120, 4), 23),
#  ((8, 4), 57),
#  ((176, 4), 55),
#  ((50, 4), 87),
#  ((190, 4), 47),
#  ((84, 4), 84),
#  ((64, 4), 109),
#  ((30, 4), 94),
#  ((86, 4), 61),
#  ((14, 4), 80),
#  ((212, 4), 74),
#  ((154, 4), 54),
#  ((44, 4), 69),
#  ((118, 4), 69),
#  ((162, 4), 97),
#  ((78, 4), 78),
#  ((202, 4), 63),
#  ((146, 4), 32),
#  ((36, 4), 37),
#  ((160, 4), 155),
#  ((42, 4), 82),
#  ((98, 4), 24),
#  ((6, 4), 93),
#  ((148, 4), 49),
#  ((180, 4), 59),
#  ((90, 4), 139),
#  ((10, 4), 59),
#  ((104, 4), 27),
#  ((126, 4), 72),
#  ((108, 4), 106),
#  ((198, 4), 101),
#  ((4, 4), 47),
#  ((112, 4), 17),
#  ((72, 4), 28),
#  ((158, 4), 59),
#  ((60, 4), 40),
#  ((74, 4), 90),
#  ((96, 4), 68),
#  ((100, 4), 36),
#  ((182, 4), 102),
#  ((192, 4), 67),
#  ((152, 4), 28),
#  ((134, 4), 73),
#  ((92, 4), 45),
#  ((34, 4), 54),
#  ((138, 4), 55),
#  ((150, 4), 30),
#  ((140, 4), 71),
#  ((144, 4), 22),
#  ((40, 4), 51),
#  ((2, 4), 37),
#  ((54, 4), 55),
#  ((178, 4), 73),
#  ((156, 4), 49),
#  ((110, 4), 63),
#  ((188, 4), 52),
#  ((186, 4), 51),
#  ((12, 4), 47),
#  ((115, 5), 8),
#  ((41, 5), 35),
#  ((163, 5), 53),
#  ((203, 5), 12),
#  ((65, 5), 64),
#  ((211, 5), 16),
#  ((175, 5), 115),
#  ((71, 5), 28),
#  ((47, 5), 27),
#  ((49, 5), 63),
#  ((57, 5), 84),
#  ((43, 5), 86),
#  ((189, 5), 28),
#  ((199, 5), 32),
#  ((157, 5), 34),
#  ((187, 5), 50),
#  ((53, 5), 37),
#  ((83, 5), 48),
#  ((19, 5), 37),
#  ((121, 5), 17),
#  ((9, 5), 28),
#  ((147, 5), 10),
#  ((75, 5), 26),
#  ((149, 5), 59),
#  ((143, 5), 17),
#  ((169, 5), 43),
#  ((183, 5), 37),
#  ((195, 5), 20),
#  ((63, 5), 26),
#  ((193, 5), 11),
#  ((89, 5), 23),
#  ((209, 5), 7),
#  ((217, 5), 15),
#  ((153, 5), 22),
#  ((91, 5), 15),
#  ((135, 5), 61),
#  ((87, 5), 20),
#  ((3, 5), 9),
#  ((31, 5), 32),
#  ((7, 5), 16),
#  ((123, 5), 16),
#  ((79, 5), 34),
#  ((213, 5), 42),
#  ((159, 5), 17),
#  ((93, 5), 7),
#  ((33, 5), 4),
#  ((215, 5), 22),
#  ((131, 5), 44),
#  ((17, 5), 31),
#  ((35, 5), 12),
#  ((85, 5), 14),
#  ((181, 5), 15),
#  ((139, 5), 45),
#  ((207, 5), 29),
#  ((25, 5), 14),
#  ((37, 5), 32),
#  ((219, 5), 27),
#  ((151, 5), 3),
#  ((59, 5), 41),
#  ((67, 5), 28),
#  ((117, 5), 21),
#  ((1, 5), 11),
#  ((5, 5), 30),
#  ((95, 5), 21),
#  ((69, 5), 18),
#  ((81, 5), 22),
#  ((107, 5), 9),
#  ((161, 5), 51),
#  ((197, 5), 36),
#  ((77, 5), 26),
#  ((101, 5), 15),
#  ((133, 5), 14),
#  ((177, 5), 36),
#  ((185, 5), 42),
#  ((55, 5), 39),
#  ((45, 5), 48),
#  ((125, 5), 20),
#  ((103, 5), 28),
#  ((129, 5), 41),
#  ((111, 5), 2),
#  ((13, 5), 35),
#  ((205, 5), 9),
#  ((15, 5), 11),
#  ((11, 5), 4),
#  ((21, 5), 17),
#  ((29, 5), 8),
#  ((27, 5), 25),
#  ((97, 5), 10),
#  ((73, 5), 44),
#  ((167, 5), 5),
#  ((155, 5), 18),
#  ((119, 5), 19),
#  ((39, 5), 10),
#  ((113, 5), 16),
#  ((171, 5), 14),
#  ((201, 5), 23),
#  ((127, 5), 26),
#  ((179, 5), 17),
#  ((109, 5), 1),
#  ((173, 5), 7),
#  ((165, 5), 5),
#  ((105, 5), 5),
#  ((137, 5), 16),
#  ((61, 5), 10),
#  ((51, 5), 15),
#  ((99, 5), 9),
#  ((141, 5), 15),
#  ((145, 5), 13),
#  ((132, 6), 13),
#  ((218, 6), 15),
#  ((206, 6), 4),
#  ((168, 6), 16),
#  ((136, 6), 12),
#  ((130, 6), 6),
#  ((60, 6), 3),
#  ((172, 6), 12),
#  ((128, 6), 12),
#  ((184, 6), 5),
#  ((142, 6), 19),
#  ((4, 6), 14),
#  ((134, 6), 10),
#  ((54, 6), 8),
#  ((26, 6), 23),
#  ((212, 6), 13),
#  ((194, 6), 7),
#  ((160, 6), 22),
#  ((76, 6), 57),
#  ((18, 6), 19),
#  ((174, 6), 10),
#  ((84, 6), 13),
#  ((166, 6), 6),
#  ((170, 6), 15),
#  ((200, 6), 2),
#  ((44, 6), 16),
#  ((204, 6), 16),
#  ((10, 6), 7),
#  ((180, 6), 7),
#  ((126, 6), 3),
#  ((2, 6), 5),
#  ((62, 6), 17),
#  ((20, 6), 7),
#  ((156, 6), 5),
#  ((74, 6), 10),
#  ((202, 6), 6),
#  ((90, 6), 13),
#  ((86, 6), 12),
#  ((34, 6), 9),
#  ((190, 6), 7),
#  ((64, 6), 7),
#  ((94, 6), 10),
#  ((162, 6), 7),
#  ((198, 6), 6),
#  ((116, 6), 3),
#  ((110, 6), 7),
#  ((148, 6), 16),
#  ((82, 6), 7),
#  ((48, 6), 19),
#  ((92, 6), 3),
#  ((30, 6), 9),
#  ((38, 6), 16),
#  ((28, 6), 4),
#  ((106, 6), 10),
#  ((208, 6), 22),
#  ((176, 6), 2),
#  ((6, 6), 15),
#  ((164, 6), 25),
#  ((46, 6), 13),
#  ((114, 6), 9),
#  ((154, 6), 11),
#  ((88, 6), 2),
#  ((102, 6), 6),
#  ((196, 6), 6),
#  ((58, 6), 12),
#  ((178, 6), 8),
#  ((16, 6), 9),
#  ((150, 6), 9),
#  ((104, 6), 4),
#  ((56, 6), 11),
#  ((52, 6), 6),
#  ((80, 6), 7),
#  ((210, 6), 10),
#  ((72, 6), 4),
#  ((192, 6), 4),
#  ((216, 6), 12),
#  ((182, 6), 6),
#  ((124, 6), 4),
#  ((118, 6), 16),
#  ((138, 6), 2),
#  ((12, 6), 5),
#  ((96, 6), 15),
#  ((214, 6), 14),
#  ((186, 6), 4),
#  ((158, 6), 7),
#  ((50, 6), 5),
#  ((122, 6), 3),
#  ((120, 6), 2),
#  ((98, 6), 2),
#  ((14, 6), 15),
#  ((152, 6), 1),
#  ((42, 6), 9),
#  ((188, 6), 2),
#  ((8, 6), 11),
#  ((40, 6), 6),
#  ((146, 6), 2),
#  ((108, 6), 4),
#  ((36, 6), 2),
#  ((140, 6), 13),
#  ((138, 0), 4),
#  ((2, 0), 1),
#  ((28, 0), 4),
#  ((40, 0), 8),
#  ((14, 0), 2),
#  ((16, 0), 2),
#  ((142, 0), 4),
#  ((20, 0), 4),
#  ((10, 0), 6),
#  ((160, 0), 6),
#  ((154, 0), 1),
#  ((134, 0), 2),
#  ((156, 0), 3),
#  ((144, 0), 3),
#  ((140, 0), 2),
#  ((210, 0), 13),
#  ((162, 0), 3),
#  ((18, 0), 2),
#  ((52, 0), 3),
#  ((34, 0), 5),
#  ((212, 0), 3),
#  ((180, 0), 2),
#  ((118, 0), 3),
#  ((206, 0), 7),
#  ((100, 0), 2),
#  ((194, 0), 54),
#  ((80, 0), 2),
#  ((112, 0), 3),
#  ((196, 0), 5),
#  ((170, 0), 5),
#  ((208, 0), 6),
#  ((58, 0), 1),
#  ((4, 0), 1),
#  ((30, 0), 3),
#  ((150, 0), 3),
#  ((104, 0), 8),
#  ((158, 0), 2),
#  ((56, 0), 1),
#  ((84, 0), 2),
#  ((108, 0), 4),
#  ((114, 0), 5),
#  ((204, 0), 4),
#  ((38, 0), 3),
#  ((8, 0), 1),
#  ((96, 0), 4),
#  ((178, 0), 1),
#  ((90, 0), 5),
#  ((74, 0), 4),
#  ((46, 0), 1),
#  ((130, 0), 2),
#  ((94, 0), 8),
#  ((48, 0), 1),
#  ((110, 0), 4),
#  ((214, 0), 1),
#  ((26, 0), 2),
#  ((216, 0), 4),
#  ((98, 0), 6),
#  ((128, 0), 1),
#  ((86, 0), 2),
#  ((164, 0), 2),
#  ((120, 0), 6),
#  ((132, 0), 8),
#  ((192, 0), 4),
#  ((201, 1), 3),
#  ((5, 1), 4),
#  ((95, 1), 1),
#  ((139, 1), 1),
#  ((21, 1), 4),
#  ((147, 1), 3),
#  ((51, 1), 15),
#  ((177, 1), 6),
#  ((153, 1), 1),
#  ((11, 1), 6),
#  ((61, 1), 3),
#  ((183, 1), 4),
#  ((175, 1), 3),
#  ((93, 1), 1),
#  ((73, 1), 1),
#  ((103, 1), 1),
#  ((161, 1), 1),
#  ((187, 1), 6),
#  ((133, 1), 2),
#  ((55, 1), 7),
#  ((135, 1), 6),
#  ((171, 1), 2),
#  ((151, 1), 1),
#  ((27, 1), 1),
#  ((155, 1), 1),
#  ((213, 1), 1),
#  ((119, 1), 1),
#  ((45, 1), 2),
#  ((91, 1), 4),
#  ((43, 1), 4),
#  ((31, 1), 4),
#  ((129, 1), 2),
#  ((81, 1), 1),
#  ((79, 1), 2),
#  ((189, 1), 1),
#  ((149, 1), 1),
#  ((185, 1), 5),
#  ((37, 1), 6),
#  ((69, 1), 1),
#  ((67, 1), 1),
#  ((117, 1), 1),
#  ((191, 5), 2),
#  ((78, 6), 2),
#  ((100, 6), 1),
#  ((144, 6), 1),
#  ((148, 0), 3),
#  ((146, 0), 2),
#  ((152, 0), 6),
#  ((202, 0), 1),
#  ((198, 0), 1),
#  ((166, 0), 1),
#  ((200, 0), 4),
#  ((168, 0), 1),
#  ((76, 0), 3),
#  ((106, 0), 2),
#  ((190, 0), 2),
#  ((78, 0), 4),
#  ((88, 0), 6),
#  ((72, 0), 3),
#  ((116, 0), 7),
#  ((17, 1), 1),
#  ((13, 1), 1),
#  ((123, 1), 2),
#  ((15, 1), 1),
#  ((7, 1), 1),
#  ((3, 1), 2),
#  ((1, 1), 9),
#  ((35, 1), 2),
#  ((59, 1), 2),
#  ((39, 1), 1),
#  ((219, 1), 2),
#  ((29, 1), 2),
#  ((127, 1), 5),
#  ((57, 1), 3),
#  ((181, 1), 2),
#  ((19, 4), 116),
#  ((203, 4), 43),
#  ((213, 4), 91),
#  ((143, 4), 42),
#  ((215, 4), 34),
#  ((47, 4), 46),
#  ((21, 4), 71),
#  ((197, 4), 69),
#  ((13, 4), 96),
#  ((187, 4), 141),
#  ((175, 4), 197),
#  ((115, 4), 76),
#  ((15, 4), 37),
#  ((183, 4), 128),
#  ((139, 4), 110),
#  ((89, 4), 63),
#  ((35, 4), 38),
#  ((7, 4), 43),
#  ((199, 4), 73),
#  ((83, 4), 131),
#  ((91, 4), 99),
#  ((57, 4), 219),
#  ((81, 4), 96),
#  ((51, 4), 67),
#  ((177, 4), 110),
#  ((43, 4), 151),
#  ((149, 4), 178),
#  ((181, 4), 110),
#  ((207, 4), 83),
#  ((135, 4), 174),
#  ((49, 4), 123),
#  ((125, 4), 71),
#  ((117, 4), 44),
#  ((189, 4), 106),
#  ((185, 4), 126),
#  ((95, 4), 109),
#  ((217, 4), 32),
#  ((211, 4), 50),
#  ((147, 4), 23),
#  ((93, 4), 45),
#  ((25, 4), 47),
#  ((75, 4), 72),
#  ((195, 4), 39),
#  ((59, 4), 128),
#  ((87, 4), 43),
#  ((179, 4), 66),
#  ((63, 4), 54),
#  ((127, 4), 56),
#  ((121, 4), 48),
#  ((29, 4), 30),
#  ((79, 4), 122),
#  ((131, 4), 94),
#  ((153, 4), 54),
#  ((105, 4), 28),
#  ((169, 4), 116),
#  ((209, 4), 52),
#  ((65, 4), 151),
#  ((171, 4), 65),
#  ((133, 4), 74),
#  ((11, 4), 52),
#  ((55, 4), 100),
#  ((27, 4), 49),
#  ((37, 4), 56),
#  ((17, 4), 92),
#  ((109, 4), 39),
#  ((145, 4), 102),
#  ((31, 4), 85),
#  ((151, 4), 30),
#  ((85, 4), 47),
#  ((71, 4), 55),
#  ((157, 4), 119),
#  ((3, 4), 93),
#  ((41, 4), 163),
#  ((5, 4), 47),
#  ((123, 4), 85),
#  ((97, 4), 37),
#  ((219, 4), 98),
#  ((113, 4), 76),
#  ((99, 4), 64),
#  ((103, 4), 73),
#  ((33, 4), 43),
#  ((67, 4), 87),
#  ((163, 4), 161),
#  ((201, 4), 55),
#  ((101, 4), 54),
#  ((39, 4), 28),
#  ((159, 4), 29),
#  ((161, 4), 143),
#  ((45, 4), 142),
#  ((53, 4), 129),
#  ((165, 4), 38),
#  ((167, 4), 47),
#  ((1, 4), 56),
#  ((155, 4), 45),
#  ((9, 4), 104),
#  ((191, 4), 37),
#  ((77, 4), 93),
#  ((141, 4), 55),
#  ((61, 4), 28),
#  ((129, 4), 110),
#  ((193, 4), 30),
#  ((111, 4), 31),
#  ((69, 4), 53),
#  ((137, 4), 66),
#  ((73, 4), 69),
#  ((205, 4), 36),
#  ((107, 4), 38),
#  ((119, 4), 30),
#  ((173, 4), 18),
#  ((42, 5), 23),
#  ((134, 5), 41),
#  ((166, 5), 24),
#  ((168, 5), 38),
#  ((114, 5), 30),
#  ((90, 5), 58),
#  ((76, 5), 25),
#  ((198, 5), 25),
#  ((80, 5), 27),
#  ((132, 5), 99),
#  ((200, 5), 13),
#  ((216, 5), 14),
#  ((176, 5), 25),
#  ((170, 5), 31),
#  ((18, 5), 36),
#  ((130, 5), 36),
#  ((62, 5), 31),
#  ((12, 5), 20),
#  ((84, 5), 32),
#  ((184, 5), 24),
#  ((214, 5), 27),
#  ((212, 5), 36),
#  ((20, 5), 17),
#  ((118, 5), 22),
#  ((116, 5), 22),
#  ((8, 5), 26),
#  ((208, 5), 73),
#  ((156, 5), 18),
#  ((50, 5), 20),
#  ((178, 5), 17),
#  ((56, 5), 36),
#  ((204, 5), 27),
#  ((26, 5), 37),
#  ((82, 5), 27),
#  ((86, 5), 30),
#  ((172, 5), 35),
#  ((44, 5), 37),
#  ((202, 5), 21),
#  ((154, 5), 22),
#  ((180, 5), 38),
#  ((30, 5), 10),
#  ((74, 5), 41),
#  ((188, 5), 10),
#  ((160, 5), 42),
#  ((138, 5), 10),
#  ((190, 5), 14),
#  ((122, 5), 35),
#  ((34, 5), 32),
#  ((6, 5), 33),
#  ((54, 5), 19),
#  ((64, 5), 31),
#  ((38, 5), 40),
#  ((146, 5), 7),
#  ((164, 5), 33),
#  ((182, 5), 27),
#  ((96, 5), 19),
#  ((92, 5), 20),
#  ((60, 5), 10),
#  ((162, 5), 15),
#  ((136, 5), 27),
#  ((106, 5), 21),
#  ((58, 5), 41),
#  ((78, 5), 29),
#  ((128, 5), 42),
#  ((206, 5), 7),
#  ((94, 5), 18),
#  ((16, 5), 20),
#  ((46, 5), 51),
#  ((52, 5), 35),
#  ((120, 5), 18),
#  ((142, 5), 12),
#  ((108, 5), 15),
#  ((14, 5), 21),
#  ((140, 5), 5),
#  ((102, 5), 8),
#  ((192, 5), 26),
#  ((110, 5), 10),
#  ((104, 5), 23),
#  ((174, 5), 12),
#  ((36, 5), 11),
#  ((194, 5), 13),
#  ((196, 5), 22),
#  ((186, 5), 10),
#  ((126, 5), 8),
#  ((210, 5), 7),
#  ((218, 5), 17),
#  ((4, 5), 23),
#  ((48, 5), 32),
#  ((150, 5), 14),
#  ((98, 5), 6),
#  ((88, 5), 2),
#  ((112, 5), 1),
#  ((124, 5), 15),
#  ((10, 5), 14),
#  ((148, 5), 12),
#  ((40, 5), 13),
#  ((72, 5), 13),
#  ((100, 5), 3),
#  ((144, 5), 5),
#  ((158, 5), 19),
#  ((152, 5), 18),
#  ((2, 5), 5),
#  ((29, 6), 4),
#  ((41, 6), 14),
#  ((157, 6), 17),
#  ((219, 6), 10),
#  ((149, 6), 31),
#  ((207, 6), 8),
#  ((121, 6), 5),
#  ((169, 6), 12),
#  ((63, 6), 15),
#  ((117, 6), 11),
#  ((215, 6), 7),
#  ((197, 6), 7),
#  ((195, 6), 12),
#  ((75, 6), 47),
#  ((135, 6), 18),
#  ((77, 6), 8),
#  ((123, 6), 11),
#  ((209, 6), 5),
#  ((131, 6), 22),
#  ((139, 6), 21),
#  ((25, 6), 5),
#  ((163, 6), 26),
#  ((39, 6), 4),
#  ((85, 6), 12),
#  ((155, 6), 21),
#  ((111, 6), 3),
#  ((91, 6), 4),
#  ((103, 6), 14),
#  ((57, 6), 31),
#  ((33, 6), 4),
#  ((31, 6), 17),
#  ((199, 6), 8),
#  ((181, 6), 8),
#  ((65, 6), 21),
#  ((83, 6), 13),
#  ((49, 6), 26),
#  ((115, 6), 5),
#  ((45, 6), 15),
#  ((59, 6), 41),
#  ((179, 6), 19),
#  ((173, 6), 7),
#  ((37, 6), 10),
#  ((127, 6), 12),
#  ((55, 6), 15),
#  ((95, 6), 11),
#  ((175, 6), 37),
#  ((67, 6), 59),
#  ((189, 6), 8),
#  ((15, 6), 6),
#  ((13, 6), 18),
#  ((51, 6), 6),
#  ((81, 6), 23),
#  ((143, 6), 7),
#  ((17, 6), 18),
#  ((217, 6), 15),
#  ((71, 6), 6),
#  ((185, 6), 6),
#  ((89, 6), 8),
#  ((5, 6), 14),
#  ((177, 6), 11),
#  ((133, 6), 19),
#  ((19, 6), 18),
#  ((183, 6), 19),
#  ((47, 6), 1),
#  ((187, 6), 17),
#  ((171, 6), 7),
#  ((73, 6), 6),
#  ((53, 6), 7),
#  ((145, 6), 12),
#  ((211, 6), 4),
#  ((213, 6), 33),
#  ((97, 6), 2),
#  ((9, 6), 7),
#  ((107, 6), 9),
#  ((1, 6), 6),
#  ((153, 6), 6),
#  ((79, 6), 12),
#  ((137, 6), 15),
#  ((3, 6), 6),
#  ((35, 6), 5),
#  ((193, 6), 3),
#  ((201, 6), 15),
#  ((43, 6), 15),
#  ((129, 6), 16),
#  ((21, 6), 4),
#  ((125, 6), 5),
#  ((93, 6), 2),
#  ((141, 6), 10),
#  ((161, 6), 8),
#  ((69, 6), 2),
#  ((87, 6), 6),
#  ((11, 6), 8),
#  ((7, 6), 17),
#  ((147, 6), 8),
#  ((203, 6), 4),
#  ((191, 6), 2),
#  ((113, 6), 4),
#  ((57, 0), 3),
#  ((1, 0), 4),
#  ((29, 0), 3),
#  ((35, 0), 1),
#  ((67, 0), 4),
#  ((165, 0), 1),
#  ((205, 0), 2),
#  ((143, 0), 1),
#  ((33, 0), 1),
#  ((209, 0), 1),
#  ((159, 0), 7),
#  ((153, 0), 4),
#  ((149, 0), 3),
#  ((7, 0), 2),
#  ((93, 0), 3),
#  ((151, 0), 4),
#  ((37, 0), 3),
#  ((27, 0), 5),
#  ((219, 0), 1),
#  ((41, 0), 2),
#  ((49, 0), 2),
#  ((39, 0), 2),
#  ((69, 0), 3),
#  ((173, 0), 6),
#  ((85, 0), 4),
#  ((177, 0), 5),
#  ((117, 0), 5),
#  ((31, 0), 2),
#  ((147, 0), 2),
#  ((109, 0), 3),
#  ((3, 0), 3),
#  ((77, 0), 9),
#  ((43, 0), 2),
#  ((95, 0), 4),
#  ((47, 0), 1),
#  ((25, 0), 2),
#  ((97, 0), 5),
#  ((107, 0), 14),
#  ((201, 0), 4),
#  ((101, 0), 5),
#  ((197, 0), 4),
#  ((169, 0), 3),
#  ((125, 0), 2),
#  ((11, 0), 2),
#  ((9, 0), 8),
#  ((63, 0), 1),
#  ((207, 0), 6),
#  ((115, 0), 3),
#  ((81, 0), 8),
#  ((111, 0), 3),
#  ((203, 0), 2),
#  ((145, 0), 1),
#  ((51, 0), 3),
#  ((79, 0), 2),
#  ((103, 0), 5),
#  ((83, 0), 8),
#  ((163, 0), 1),
#  ((13, 0), 1),
#  ((87, 0), 3),
#  ((75, 0), 5),
#  ((133, 0), 6),
#  ((5, 0), 2),
#  ((191, 0), 3),
#  ((91, 0), 3),
#  ((121, 0), 2),
#  ((119, 0), 8),
#  ((195, 0), 4),
#  ((171, 0), 3),
#  ((213, 0), 2),
#  ((55, 0), 2),
#  ((26, 1), 7),
#  ((116, 1), 2),
#  ((12, 1), 2),
#  ((166, 1), 1),
#  ((170, 1), 3),
#  ((90, 1), 2),
#  ((44, 1), 2),
#  ((162, 1), 1),
#  ((120, 1), 2),
#  ((154, 1), 2),
#  ((62, 1), 6),
#  ((200, 1), 1),
#  ((214, 1), 1),
#  ((124, 1), 4),
#  ((84, 1), 7),
#  ((72, 1), 1),
#  ((34, 1), 3),
#  ((164, 1), 1),
#  ((108, 1), 4),
#  ((192, 1), 3),
#  ((144, 1), 2),
#  ((128, 1), 1),
#  ((216, 1), 2),
#  ((38, 1), 2),
#  ((40, 1), 2),
#  ((210, 1), 2),
#  ((160, 1), 3),
#  ((176, 1), 1),
#  ((28, 1), 2),
#  ((46, 1), 3),
#  ((142, 1), 2),
#  ((64, 1), 3),
#  ((54, 1), 5),
#  ((202, 1), 1),
#  ((52, 1), 2),
#  ((180, 1), 2),
#  ((78, 1), 1),
#  ((136, 1), 16),
#  ((182, 1), 5),
#  ((184, 1), 8),
#  ((74, 1), 1),
#  ((152, 1), 1),
#  ((198, 1), 1),
#  ((118, 1), 1),
#  ((16, 1), 2),
#  ((80, 1), 1),
#  ((36, 1), 1),
#  ((28, 5), 3),
#  ((27, 6), 1),
#  ((99, 6), 1),
#  ((165, 6), 2),
#  ((205, 6), 2),
#  ((101, 6), 2),
#  ((167, 6), 1),
#  ((119, 6), 2),
#  ((151, 6), 1),
#  ((139, 0), 5),
#  ((161, 0), 3),
#  ((211, 0), 2),
#  ((155, 0), 3),
#  ((167, 0), 3),
#  ((99, 0), 1),
#  ((199, 0), 1),
#  ((113, 0), 3),
#  ((193, 0), 2),
#  ((131, 0), 3),
#  ((61, 0), 2),
#  ((105, 0), 4),
#  ((65, 0), 1),
#  ((189, 0), 3),
#  ((73, 0), 2),
#  ((4, 1), 2),
#  ((6, 1), 1),
#  ((58, 1), 1),
#  ((122, 1), 3),
#  ((14, 1), 1),
#  ((30, 1), 1),
#  ((174, 1), 2),
#  ((8, 1), 2),
#  ((18, 1), 1),
#  ((2, 1), 5),
#  ((82, 1), 2),
#  ((218, 1), 3),
#  ((10, 1), 2),
#  ((50, 1), 3),
#  ((134, 1), 2),
#  ((126, 1), 4),
#  ((178, 1), 2),
#  ((48, 1), 4)]

# %%
viajes_totales_semana.take(1)
# Out:
# [((16, 4), 58)]

# %% [markdown]
# Dado umbral,estaciones distritos mas repreentativos

# %%
def create_list_media(rdd_lista):
  """"
  Devuelve una lista de listas
  valor1: 0 si es lunes, 1 si es martes, etc.
  valor2: lista con nº estacion/nombre del distrito y nº de viajes que ha hecho maas que la media.
  """
  i = 0
  lista=[]
  lunes=[]
  martes=[]
  miercoles=[]
  jueves=[]
  viernes=[]
  sabado=[]
  domingo=[]
  while i < len(rdd_lista):
    dia = rdd_lista[i][0][1]
    estacion = rdd_lista[i][0][0]
    diferencia_viajes = round(rdd_lista[i][1][0][0] - rdd_lista[i][1][1][0])
    if dia == 0:
      lunes.append([estacion,diferencia_viajes])
    elif dia == 1:
      martes.append([estacion,diferencia_viajes])
    elif dia == 2:
      miercoles.append([estacion,diferencia_viajes])
    elif dia == 3:
      jueves.append([estacion,diferencia_viajes])
    elif dia == 4:
      viernes.append([estacion,diferencia_viajes])
    elif dia == 5:
      sabado.append([estacion,diferencia_viajes])
    elif dia == 6:
      domingo.append([estacion,diferencia_viajes])
    i += 1
  i=0
  while i < 7:
    if i == 0:
      lista.append([i]+lunes)
    elif i == 1:
      lista.append([i]+martes)
    elif i == 2:
      lista.append([i]+miercoles)
    elif i == 3:
      lista.append([i]+jueves)
    elif i == 4:
      lista.append([i]+viernes)
    elif i == 5:
      lista.append([i]+sabado)
    elif i == 6:
      lista.append([i]+domingo)
    i += 1
  return lista

# %%
#json de medias de llegadas 
with open('/home/mat/Escritorio/uso_medio_llegadas.json','r') as fichero:
  lista_llegadas = json.load(fichero)   #id,weekday,media
#json de medias de salidas
with open('/home/mat/Escritorio/uso_medio_salidas.json','r') as fichero:
  lista_salidas = json.load(fichero)   #id,weekday,media
#diccionario {estación:distrito} . Lo usaremos para pasar de estación a distrito
with open('/home/mat/Escritorio/dictBarrio.json','r') as fichero:
   dic_distritos = json.load(fichero)  
    
rdd_media_llegadas = sc.parallelize(lista_llegadas)
rdd_media_salidas = sc.parallelize(lista_salidas)

# %%
rdd_media_llegadas.take(1)
# Out:
# [[189, 0, 46.666666666666664]]

# %%
rdd_media_salidas.take(1)
# Out:
# [[189, 0, 39.666666666666664]]

# %%
def aux1(line):
  """
  Parámetro: linea de la rdd
  Conserva la clave y cambia el valor a una lista de ese mismo valor
  Se utilizará en el estudio de estaciones
  """
  dia_estacion = line[0]
  cant = len(line[1])
  return dia_estacion,[cant]

# %%
def estacion_llegadas_dia(line):
  """
  Parámetro: linea de la rdd 
  Devuelve: estación de llegada y número que corresponde al día(lunes 0, martes1), 1 de viaje realizado
  """
  linea = json.loads(line)
  dia = int(linea['unplug_hourTime'][8:10])
  estacion = linea['idplug_station']
  if dia == dia_inicial:
    dia = 0
  elif dia == dia_inicial + 1:
    dia = 1
  elif dia == dia_inicial + 2:
    dia = 2
  elif dia == dia_inicial + 3:
    dia = 3
  elif dia == dia_inicial + 4:
    dia = 4
  elif dia == dia_inicial + 5:
    dia = 5
  elif dia == dia_final:
    dia = 6
  return (estacion,dia),1

# %%
estacion_llegadas_dia(line)
# Out:
# ((108, 4), 1)

# %%
def estacion_salidas_dia(line):
  """
  Parámetro: linea de la rdd 
  Devuelve: estación de salida y número que corresponde al día(lunes 0, martes1), 1 de viaje realizado
  """
  linea = json.loads(line)
  dia = int(linea['unplug_hourTime'][8:10])
  estacion = linea['idunplug_station']
  if dia == dia_inicial:
    dia = 0
  elif dia == dia_inicial+1:
    dia = 1
  elif dia == dia_inicial+2:
    dia = 2
  elif dia == dia_inicial+3:
    dia = 3
  elif dia == dia_inicial + 4:
    dia = 4
  elif dia == dia_inicial +5:
    dia = 5
  elif dia == dia_final:
    dia = 6
  return (estacion,dia),1

# %%
estacion_salidas_dia(line)
# Out:
# ((136, 4), 1)

# %%
def estacion_por_distrito(line):
  """
  Parámetro: linea de la rdd con key: (estación,dia) y value: media(rdd media)/1 (rdd semana), 
  Se cambia estación por distrito usando el diccionario
  """
  estacion = str(line[0][0])
  dia = line[0][1]
  media = line[1]
  if estacion == '80' or estacion == '1' or estacion == '111' or estacion == '116' or estacion == '25' or estacion == '128' or estacion == '90' or estacion == '161' or estacion=='20':
    if len(estacion) == 1:
      estacion = '00'+estacion
    elif len(estacion) == 2:
      estacion = '0'+estacion
    if estacion == '128' or estacion == '090' or estacion == '161' or estacion=='020':
      estacion = estacion + ' ampliacion'
    else:
      estacion = estacion + ' a'
  distrito = dic_distritos[estacion]
  return (distrito,dia),media

# %%
def media_medias_distritos(line):
  """
  Parámetro: linea de la rdd (rdd medias)
  hacemos media de las medias para ver la media de los distritos
  """
  estacion_dia = line[0]
  lista_de_medias = line[1]
  new_media=(sum(int(i) for i in lista_de_medias))/len(lista_de_medias)
  return estacion_dia,[new_media]

# %%
#llegadas por estacion
media_llegadas_estacion = rdd_media_llegadas.map(lambda x: ((x[0],x[1]),x[2])).groupByKey().mapValues(list)
estacion_dia_llegadas = rdd_semana.map(estacion_llegadas_dia).groupByKey().map(aux1)
llegada_estacion = estacion_dia_llegadas.join(media_llegadas_estacion).filter(lambda x: x[1][0][0] > x[1][1][0]+ Umbral_estaciones).collect()
lista_llegadas_estacion = create_list_media(llegada_estacion)
    
  #salidas por estacion
media_salidas_estacion = rdd_media_salidas.map(lambda x: ((x[0],x[1]),x[2])).groupByKey().mapValues(list)
estacion_dia_salidas = rdd_semana.map(estacion_salidas_dia).groupByKey().map(aux1)
salida_estacion = estacion_dia_salidas.join(media_salidas_estacion).filter(lambda x: x[1][0][0] > x[1][1][0]+Umbral_estaciones).collect()
lista_salidas_estacion = create_list_media(salida_estacion)

# %%
media_llegadas_estacion.take(1)
# Out:
# [((189, 0), [46.666666666666664])]

# %%
media_salidas_estacion.take(1)
# Out:
# [((189, 0), [39.666666666666664])]

# %%
#llegadas por distritos
distrito_llegadas = rdd_semana.map(estacion_llegadas_dia).filter(lambda x: x[0][0]!= 66 and x[0][0]!= 64 and x[0][0]!=21 and x[0][0]!=28 and x[0][0]< 212).map(estacion_por_distrito).groupByKey().map(aux1)
distrito_medias_llegadas=rdd_media_llegadas.map(lambda x: ((x[0],x[1]),x[2])).filter(lambda x: x[0][0]!= 66 and x[0][0]!= 64 and x[0][0]!=21 and x[0][0]!=28 and x[0][0]<212).map(estacion_por_distrito).groupByKey().mapValues(list).map(media_medias_distritos)
llegadas_distritos = distrito_llegadas.join(distrito_medias_llegadas).filter(lambda x: x[1][0][0] > x[1][1][0]+Umbral_distritos).collect()
lista_llegadas_distritos = create_list_media(llegadas_distritos)
    
  #salidas por distritos
distrito_salidas = rdd_semana.map(estacion_salidas_dia).filter(lambda x: x[0][0]!= 66 and x[0][0]!= 64 and x[0][0]!=21 and x[0][0]!=28 and x[0][0]<212).map(estacion_por_distrito).groupByKey().map(aux1)
distrito_medias_salidas=rdd_media_salidas.map(lambda x: ((x[0],x[1]),x[2])).filter(lambda x: x[0][0]!= 66 and x[0][0]!= 64 and x[0][0]!=21 and x[0][0]!=28 and x[0][0]<212).map(estacion_por_distrito).groupByKey().mapValues(list).map(media_medias_distritos)
salidas_distritos = distrito_salidas.join(distrito_medias_salidas).filter(lambda x: x[1][0][0] > x[1][1][0]+Umbral_distritos).collect()
lista_salidas_distritos=create_list_media(salidas_distritos)

# %%
distrito_medias_llegadas.take(1)
# Out:
# [(('CONCEPCIÓN', 0), [46.0])]

# %%
distrito_medias_salidas.take(1)
# Out:
# [(('CONCEPCIÓN', 0), [39.0])]

# %% [markdown]
# 5 estaciones más importantes en la semana

# %%
def salidas_mapper(line):
  """
  sacamos de la rdd :estacion_inicio, estacion_final
  """
  try:
    linea = json.loads(line)
    inicio = linea['idunplug_station']
    final = linea['idplug_station']
  except:
    inicio = line['idunplug_station']
    final = line['idplug_station']    
  return inicio,final


def llegadas_mapper(line):
  """
  sacamos de la rdd :estacion_final,estacion_inicio
  """
  try: 
    linea = json.loads(line)
    inicio = linea['idunplug_station']
    final = linea['idplug_station']
  except: 
    inicio = line['idunplug_station']
    final = line['idunplug_station']
  return final,inicio



def lista_viajes_totales(rddinicial):
    """
    Usamos rdd semana
    devuelve lista decreciente por numero de viajes totales en formato:
    (estacion, nº salidas, nº llegadas, nº viajes totales)
   
    """
    lista_llegadas_numero = rddinicial.map(llegadas_mapper).groupByKey().mapValues(list)
    viajes_totales = rddinicial.map(salidas_mapper).groupByKey().mapValues(list).cogroup(lista_llegadas_numero).map(lambda x: (x[0],len(list(x[1][0])[0]), len(list(x[1][1])[0]),len(list(x[1][0])[0]) + len(list(x[1][1])[0]) ))
    lista_viajes_totales = viajes_totales.collect()
    return sorted(lista_viajes_totales, key=itemgetter(3), reverse = True)


def lista_viajes_totales_top(rddinicial):
  """
  usamos rdd semana
  devuelve lista con top 5 estaciones más importantes según nuúmero de viajes en formato:
  (estacion, nº viajes totales )
  """
  viajes = lista_viajes_totales(rddinicial)
  i = 0
  listaaux = []
  while i < 5:
    tupla_estacion_viajes = (viajes[i][0],viajes[i][3])
    listaaux.append(tupla_estacion_viajes)
    i = i+1
  return listaaux

# %%
lista_top_5 = lista_viajes_totales_top(rdd_semana)
print("------------------------------------------------")
print("Top 5 estaciones más usadas en la semana elegida")
for i in range(5):
    print(f"{lista_top_5[i][0]}:{lista_top_5[i][1]}")
print("------------------------------------------------")
# Out:
# ------------------------------------------------
# Top 5 estaciones más usadas en la semana elegida
# 175:352
# 57:340
# 208:284
# 149:272
# 135:259
# ------------------------------------------------
